# %% [markdown]
# # Начальная инициализация

# %%
import datetime
print(datetime.datetime.now().strftime('%d-%B-%Y %H:%M:%S'))
# Out:
# 10-March-2023 07:56:07

# %%
import lightning
import gensim
import pickle
import numpy as np
import pandas as pd
import nltk
import pymorphy3
import re
import os
from tqdm import tqdm
import random
import torch
import sklearn.model_selection
import torchmetrics
import IPython.display

# scripts
from scripts.rus_preprocessing_udpipe import Preprocessing

# Download nltk data if it is not present
# nltk.download('punkt)
# nltk.download('stopwords')

random_state = 42
random.seed(random_state)
np.random.seed(random_state)

# %%
def word_averaging(model, words):
    all_words, mean = set(), []

    for word in words:
        if hasattr(model, "key_to_index"):
            if word in model.key_to_index:
                mean.append(model[model.key_to_index[word]])
                all_words.add(word)
        else:
            if word in model.wv:
                mean.append(model.wv[word])
                all_words.add(word)

    if not mean:
        return np.zeros(model.vector_size)

    mean = gensim.matutils.unitvec(np.array(mean).mean(axis=0)).astype(np.float32)

    return mean


def word_averaging_list(model, text_list):
    return np.vstack([word_averaging(model, comment_text) for comment_text in tqdm(text_list)])

# %%
print(datetime.datetime.now().strftime('%d-%B-%Y %H:%M:%S'))
# Out:
# 10-March-2023 07:56:12

# %% [markdown]
# # Предобработка текста

# %%
DATAPATH = 'data/'
train = pd.read_csv(DATAPATH + 'X_y_train.csv', sep=';')
test = pd.read_csv(DATAPATH + 'X_y_test.csv', sep=';')

X_train = [el[0] for el in train[['Text']].values]
X_test = [el[0] for el in test[['Text']].values]
y_train = [el[0] for el in train[['Class']].replace(-1, 0).values]
y_test = [el[0] for el in test[['Class']].replace(-1, 0).values]

# %%
def tokenize(text, morph):
  text = re.sub('[^А-Яа-я\s]', '', text).strip()
  tokens = nltk.word_tokenize(text.lower())
  tokens = [morph.parse(el)[0].normal_form for el in tokens]
  tokens = [el for el in tokens if el not in nltk.corpus.stopwords.words('russian')]
  return tokens

morph = pymorphy3.MorphAnalyzer()
X_train_token = [tokenize(t, morph) for t in tqdm(X_train)]
X_test_token = [tokenize(t, morph) for t in tqdm(X_test)]
# Out:
# 100%|██████████| 22348/22348 [03:01<00:00, 122.89it/s]
# 100%|██████████| 50/50 [00:00<00:00, 123.83it/s]

# %% [markdown]
# # Word2vec

# %% [markdown]
# ## Self-trained

# %%
w2v_model = gensim.models.Word2Vec(sentences=X_train_token, vector_size=300, window=5, min_count=1, workers=os.cpu_count(), seed=random_state)
w2v_model.build_vocab(X_train_token)
w2v_model.train(X_train_token, total_examples=w2v_model.corpus_count, epochs=300, report_delay=1)

# save trained model
# !mkdir self-trained_word2vec
# w2v_model.save('self-trained_word2vec/word2vec.model')
# Out:
# (45340485, 47914800)

# %%
X_train_w2v_self_trained = word_averaging_list(w2v_model, X_train_token)
X_test_w2v_self_trained = word_averaging_list(w2v_model, X_test_token)
# Out:
# 100%|██████████| 22348/22348 [00:01<00:00, 12751.99it/s]
# 100%|██████████| 50/50 [00:00<00:00, 10027.98it/s]

# %%
print(datetime.datetime.now().strftime('%d-%B-%Y %H:%M:%S'))
# Out:
# 10-March-2023 07:57:24

# %% [markdown]
# ## Pre-trained

# %% [markdown]
# Udpipe разметка

# %%
X_train_token_pre_trained = []
preprocessing = Preprocessing(udpipe_filename='models/udpipe_syntagrus.model')
for input_line in tqdm(X_train_token):
    input_line = ' '.join(input_line) # need to concat tokens with preprocessing
    res = preprocessing.unify_sym(input_line.strip())
    output = preprocessing.process(text=res)
    X_train_token_pre_trained.append(output)


X_test_token_pre_trained = []
for input_line in tqdm(X_test_token):
    input_line = ' '.join(input_line) # need to concat tokens with preprocessing
    res = preprocessing.unify_sym(input_line.strip())
    output = preprocessing.process(text=res)
    X_test_token_pre_trained.append(output)
# Out:
# 100%|██████████| 22348/22348 [02:45<00:00, 134.65it/s]
# 100%|██████████| 50/50 [00:00<00:00, 136.70it/s]

# %%
w2v_model = gensim.models.KeyedVectors.load_word2vec_format('models/word2vec/model.bin', encoding='utf-8', unicode_errors='ignore', binary=True)
w2v_model.fill_norms(force=True)

X_train_w2v_pre_trained = word_averaging_list(w2v_model, X_train_token_pre_trained)
X_test_w2v_pre_trained = word_averaging_list(w2v_model, X_test_token_pre_trained)
# Out:
# 100%|██████████| 22348/22348 [00:01<00:00, 13651.16it/s]
# 100%|██████████| 50/50 [00:00<00:00, 12632.68it/s]

# %% [markdown]
# # FastText

# %% [markdown]
# ## Self-trained

# %%
ft_model = gensim.models.FastText(sentences=X_train_token, vector_size=300, window=5, min_count=1, workers=os.cpu_count(), seed=random_state)
ft_model.build_vocab(X_train_token)
ft_model.train(X_train_token, total_examples=ft_model.corpus_count, epochs=300, report_delay=1)

# save trained model
# !mkdir self-trained_fasttext
# ft_model.save('self-trained_fasttext/fasttext.model')
# Out:
# (45341567, 47914800)

# %%
X_train_ft_self_trained = word_averaging_list(ft_model, X_train_token)
X_test_ft_self_trained = word_averaging_list(ft_model, X_test_token)
# Out:
# 100%|██████████| 22348/22348 [00:01<00:00, 13206.11it/s]
# 100%|██████████| 50/50 [00:00<00:00, 5550.52it/s]

# %%
print(datetime.datetime.now().strftime('%d-%B-%Y %H:%M:%S'))
# Out:
# 10-March-2023 09:13:34

# %% [markdown]
# ## Pre-trained

# %%
ft_model = gensim.models.KeyedVectors.load('models/fasttext/model.model')
ft_model.fill_norms(force=True)

X_train_ft_pre_trained = word_averaging_list(ft_model, X_train_token)
X_test_ft_pre_trained = word_averaging_list(ft_model, X_test_token)
# Out:
# 100%|██████████| 22348/22348 [00:04<00:00, 4529.82it/s]
# 100%|██████████| 50/50 [00:00<00:00, 2944.28it/s]

# %%
print(datetime.datetime.now().strftime('%d-%B-%Y %H:%M:%S'))
# Out:
# 10-March-2023 09:13:34

# %% [markdown]
# # Сохранение полученных признаков в pickle

# %%
def save_pickle(obj, filename: str) -> None:
    pickle.dump(obj, file=open('dumps/' + filename, mode="wb"))
    return

# FastText
save_pickle(X_train_ft_pre_trained, 'X_train_ft_pre_trained' + '.pkl')
save_pickle(X_test_ft_pre_trained, 'X_test_ft_pre_trained' + '.pkl')
save_pickle(X_train_ft_self_trained, 'X_train_ft_self_trained' + '.pkl')
save_pickle(X_test_ft_self_trained, 'X_test_ft_self_trained' + '.pkl')

# Word2Vec
save_pickle(X_train_w2v_pre_trained, 'X_train_w2v_pre_trained' + '.pkl')
save_pickle(X_test_w2v_pre_trained, 'X_test_w2v_pre_trained' + '.pkl')
save_pickle(X_train_w2v_self_trained, 'X_train_w2v_self_trained' + '.pkl')
save_pickle(X_test_w2v_self_trained, 'X_test_w2v_self_trained' + '.pkl')

# %% [markdown]
# # Обучение нейронных сетей

# %% [markdown]
# Воспроизводимость результатов

# %%
lightning.seed_everything(random_state, workers=True)
# Out:
# Global seed set to 42
# 42

# %% [markdown]
# Сетка перебираемых гиперпараметров

# %%
param_grid = {
    'embeddings': ['w2v_pretrained', 'ft_pretrained', 'w2v_selftrained', 'ft_selftrained'],
    'layers_count': [2, 3, 4],
    'learning_rate': [0.01, 0.001],
    'layers_type': ['different', 'equal'],
    'batch_size': [8, 64],
    'optimizer': [torch.optim.SGD, torch.optim.AdamW],
    'epochs': [5, 10],
    'activation_function': [torch.nn.functional.relu],
}

params_list = sklearn.model_selection.ParameterGrid(param_grid)
len(params_list)
# Out:
# 384

# %% [markdown]
# Класс для работы с данными

# %%
class NetData(lightning.LightningDataModule):
    def __init__(self, train_features=None, test_features=None, train_targets=None, test_targets=None, batch_size=None, random_state=None):
        super().__init__()
        
        self.batch_size = batch_size
        self.X_train, self.X_val, self.y_train, self.y_val = sklearn.model_selection.train_test_split(train_features, train_targets, random_state=random_state)
        self.X_test, self.y_test = test_features, test_targets

    def setup(self, stage=None):
        features_train = torch.tensor(self.X_train, dtype=torch.float32)
        targets_train = torch.tensor(self.y_train, dtype=torch.int32)
    
        features_val = torch.tensor(self.X_val, dtype=torch.float32)
        targets_val = torch.tensor(self.y_val, dtype=torch.int32)
    
        features_test = torch.tensor(self.X_test, dtype=torch.float32)
        targets_test = torch.tensor(self.y_test, dtype=torch.int32)
    
        self.trainset = torch.utils.data.TensorDataset(features_train, targets_train)
        self.valset = torch.utils.data.TensorDataset(features_val, targets_val)
        self.testset = torch.utils.data.TensorDataset(features_test, targets_test)
        
    def train_dataloader(self):
        return torch.utils.data.DataLoader(self.trainset, batch_size=self.batch_size)
    def val_dataloader(self):
        return torch.utils.data.DataLoader(self.valset, batch_size=self.batch_size)
    def test_dataloader(self):
        return torch.utils.data.DataLoader(self.testset, batch_size=self.batch_size)

# %% [markdown]
# Нейронная сеть

# %%
#Архитектура нейронной сети
class Net(lightning.LightningModule):
    def __init__(self,
                 learning_rate=None,
                 layers_count=None,
                 layers_type=None,
                 optimizer=None,
                 activation=None
                 ):
        
        super().__init__()  #вх. #вых.
        self.layers = torch.nn.ModuleList()
        input_dim = 2**(2 + layers_count)
        self.layers.append(torch.nn.Linear(300, input_dim))
        for _ in range(layers_count):
            if layers_type == 'equal':
                self.layers.append( torch.nn.Linear(input_dim, input_dim) )
            elif layers_type == "different":
                self.layers.append( torch.nn.Linear(input_dim, input_dim // 2) )
                input_dim //= 2
        self.layers.append(torch.nn.Linear(input_dim, 2))

        self.activation = activation

        self.learning_rate = learning_rate
        self.optimizer = optimizer
        self.f1 = torchmetrics.classification.F1Score(task='multiclass', num_classes=2, multidim_average='global', average='weighted')

    def forward(self, x):
        for layer in self.layers[:-1]:
            x = self.activation(layer(x))
        x = self.layers[-1](x)
        return torch.nn.functional.log_softmax(x, dim=-1)
    
    def configure_optimizers(self):
        optimizer = self.optimizer(self.parameters(), lr=self.learning_rate)
        return optimizer
    
    def training_step(self, batch, batch_idx):
        x, y = batch
        y_hat = self(x)
        loss = torch.nn.functional.cross_entropy(y_hat, y.long())
        self.log('loss', loss, on_epoch=True)
        self.log("train_f1", self.f1(y_hat, y), on_epoch=True)
        return loss
    
    def validation_step(self, batch, batch_idx):
        x, y = batch
        pred = self(x)
        self.log("val_f1", self.f1(pred, y), on_epoch=True)

    def test_step(self, batch, batch_idx):
        x, y = batch
        pred = self(x)
        self.log("test_f1", self.f1(pred, y), on_epoch=True)

# %%
total = []

for params in tqdm(params_list): 

    embeddings = params['embeddings']
    learningRate = params['learning_rate']
    optimizer_type = params['optimizer']
    layers_count = params['layers_count']
    batch_size = params['batch_size']
    epochs = params['epochs']
    activation_function = params['activation_function']
    layers_type = params['layers_type']


    net = Net(learning_rate=learningRate,
          layers_count=layers_count,
          layers_type=layers_type,
          optimizer=optimizer_type,
          activation=activation_function
        )
    
    dm = None
    if embeddings == 'w2v_pretrained':
        dm = NetData(
            train_features=X_train_w2v_pre_trained,
            test_features=X_test_w2v_pre_trained,
            train_targets=y_train,
            test_targets=y_test,
            batch_size=batch_size,
            random_state=random_state
        )
    elif embeddings == 'w2v_selftrained':
        dm = NetData(
            train_features=X_train_w2v_self_trained,
            test_features=X_test_w2v_self_trained,
            train_targets=y_train,
            test_targets=y_test,
            batch_size=batch_size,
            random_state=random_state
        )
    elif embeddings == 'ft_pretrained':
        dm = NetData(
            train_features=X_train_ft_pre_trained,
            test_features=X_test_ft_pre_trained,
            train_targets=y_train,
            test_targets=y_test,
            batch_size=batch_size,
            random_state=random_state
        )
    elif embeddings == 'ft_selftrained':
        dm = NetData(
            train_features=X_train_ft_self_trained,
            test_features=X_test_ft_self_trained,
            train_targets=y_train,
            test_targets=y_test,
            batch_size=batch_size,
            random_state=random_state
        )
    

    # CPU is better for FCNN than GPU
    trainer = lightning.Trainer(logger=False, max_epochs=epochs, enable_progress_bar=True, deterministic=True, inference_mode=True, enable_checkpointing=False, accelerator='cpu')

    trainer.fit(net, datamodule=dm)
    f1_train = trainer.logged_metrics['train_f1_epoch'].item()
    f1_val = trainer.logged_metrics['val_f1'].item()
    f1_test = trainer.test(net, datamodule=dm)[-1]['test_f1']    
    
    
    total.append({
        'embeddings': embeddings,
        'Layers type': layers_type,
        'Optimizer': optimizer_type.__name__,
        'Batch': batch_size,
        'Count of layers': layers_count,
        'Epochs': epochs,
        'Learning rate': learningRate,
        'Activation function': activation_function.__name__,
        'F1-train': round(f1_train, 4),
        'F1-val': round(f1_val, 4),
        'F1-test': round(f1_test, 4)
    })
    
    IPython.display.clear_output(wait=True)
# Out:
# 100%|██████████| 384/384 [12:44:42<00:00, 119.49s/it]

# %% [markdown]
# # Сводная таблица

# %%
pd.set_option('display.max_rows', None)
summary = pd.DataFrame.from_dict(total)
summary_sort = summary.sort_values(by='F1-val', ascending=False)
summary_sort
# Out:
#           embeddings Layers type Optimizer  Batch  Count of layers  Epochs  \
# 367   ft_selftrained       equal     AdamW     64                2      10
# 171   ft_selftrained   different     AdamW      8                2      10
# 351   ft_selftrained       equal     AdamW     64                3       5
# 175   ft_selftrained       equal     AdamW      8                2      10
# 151   ft_selftrained       equal     AdamW      8                2       5
# 355   ft_selftrained   different     AdamW     64                4       5
# 155   ft_selftrained   different     AdamW      8                3       5
# 347   ft_selftrained   different     AdamW     64                3       5
# 339   ft_selftrained   different     AdamW     64                2       5
# 363   ft_selftrained   different     AdamW     64                2      10
# 343   ft_selftrained       equal     AdamW     64                2       5
# 337   ft_selftrained   different     AdamW     64                2       5
# 371   ft_selftrained   different     AdamW     64                3      10
# 379   ft_selftrained   different     AdamW     64                4      10
# 103  w2v_selftrained       equal     AdamW      8                2       5
# 361   ft_selftrained   different     AdamW     64                2      10
# 159   ft_selftrained       equal     AdamW      8                3       5
# 327  w2v_selftrained       equal     AdamW     64                3      10
# 303  w2v_selftrained       equal     AdamW     64                3       5
# 349   ft_selftrained       equal     AdamW     64                3       5
# 179   ft_selftrained   different     AdamW      8                3      10
# 123  w2v_selftrained   different     AdamW      8                2      10
# 149   ft_selftrained       equal     AdamW      8                2       5
# 341   ft_selftrained       equal     AdamW     64                2       5
# 375   ft_selftrained       equal     AdamW     64                3      10
# 381   ft_selftrained       equal     AdamW     64                4      10
# 307  w2v_selftrained   different     AdamW     64                4       5
# 321  w2v_selftrained   different     AdamW     64                3      10
# 187   ft_selftrained   different     AdamW      8                4      10
# 373   ft_selftrained       equal     AdamW     64                3      10
# 359   ft_selftrained       equal     AdamW     64                4       5
# 377   ft_selftrained   different     AdamW     64                4      10
# 383   ft_selftrained       equal     AdamW     64                4      10
# 289  w2v_selftrained   different     AdamW     64                2       5
# 319  w2v_selftrained       equal     AdamW     64                2      10
# 99   w2v_selftrained   different     AdamW      8                2       5
# 293  w2v_selftrained       equal     AdamW     64                2       5
# 353   ft_selftrained   different     AdamW     64                4       5
# 299  w2v_selftrained   different     AdamW     64                3       5
# 169   ft_selftrained   different     AdamW      8                2      10
# 317  w2v_selftrained       equal     AdamW     64                2      10
# 295  w2v_selftrained       equal     AdamW     64                2       5
# 167   ft_selftrained       equal     AdamW      8                4       5
# 107  w2v_selftrained   different     AdamW      8                3       5
# 191   ft_selftrained       equal     AdamW      8                4      10
# 291  w2v_selftrained   different     AdamW     64                2       5
# 161   ft_selftrained   different     AdamW      8                4       5
# 143  w2v_selftrained       equal     AdamW      8                4      10
# 157   ft_selftrained       equal     AdamW      8                3       5
# 365   ft_selftrained       equal     AdamW     64                2      10
# 101  w2v_selftrained       equal     AdamW      8                2       5
# 117  w2v_selftrained       equal     AdamW      8                4       5
# 111  w2v_selftrained       equal     AdamW      8                3       5
# 323  w2v_selftrained   different     AdamW     64                3      10
# 315  w2v_selftrained   different     AdamW     64                2      10
# 183   ft_selftrained       equal     AdamW      8                3      10
# 297  w2v_selftrained   different     AdamW     64                3       5
# 313  w2v_selftrained   different     AdamW     64                2      10
# 369   ft_selftrained   different     AdamW     64                3      10
# 113  w2v_selftrained   different     AdamW      8                4       5
# 141  w2v_selftrained       equal     AdamW      8                4      10
# 173   ft_selftrained       equal     AdamW      8                2      10
# 331  w2v_selftrained   different     AdamW     64                4      10
# 109  w2v_selftrained       equal     AdamW      8                3       5
# 105  w2v_selftrained   different     AdamW      8                3       5
# 135  w2v_selftrained       equal     AdamW      8                3      10
# 305  w2v_selftrained   different     AdamW     64                4       5
# 125  w2v_selftrained       equal     AdamW      8                2      10
# 201   w2v_pretrained   different     AdamW     64                3       5
# 197   w2v_pretrained       equal     AdamW     64                2       5
# 309  w2v_selftrained       equal     AdamW     64                4       5
# 205   w2v_pretrained       equal     AdamW     64                3       5
# 127  w2v_selftrained       equal     AdamW      8                2      10
# 311  w2v_selftrained       equal     AdamW     64                4       5
# 223   w2v_pretrained       equal     AdamW     64                2      10
# 325  w2v_selftrained       equal     AdamW     64                3      10
# 357   ft_selftrained       equal     AdamW     64                4       5
# 231   w2v_pretrained       equal     AdamW     64                3      10
# 119  w2v_selftrained       equal     AdamW      8                4       5
# 301  w2v_selftrained       equal     AdamW     64                3       5
# 207   w2v_pretrained       equal     AdamW     64                3       5
# 203   w2v_pretrained   different     AdamW     64                3       5
# 333  w2v_selftrained       equal     AdamW     64                4      10
# 199   w2v_pretrained       equal     AdamW     64                2       5
# 215   w2v_pretrained       equal     AdamW     64                4       5
# 27    w2v_pretrained   different     AdamW      8                2      10
# 211   w2v_pretrained   different     AdamW     64                4       5
# 124  w2v_selftrained       equal       SGD      8                2      10
# 335  w2v_selftrained       equal     AdamW     64                4      10
# 181   ft_selftrained       equal     AdamW      8                3      10
# 227   w2v_pretrained   different     AdamW     64                3      10
# 213   w2v_pretrained       equal     AdamW     64                4       5
# 235   w2v_pretrained   different     AdamW     64                4      10
# 3     w2v_pretrained   different     AdamW      8                2       5
# 219   w2v_pretrained   different     AdamW     64                2      10
# 120  w2v_selftrained   different       SGD      8                2      10
# 7     w2v_pretrained       equal     AdamW      8                2       5
# 11    w2v_pretrained   different     AdamW      8                3       5
# 193   w2v_pretrained   different     AdamW     64                2       5
# 115  w2v_selftrained   different     AdamW      8                4       5
# 23    w2v_pretrained       equal     AdamW      8                4       5
# 225   w2v_pretrained   different     AdamW     64                3      10
# 209   w2v_pretrained   different     AdamW     64                4       5
# 233   w2v_pretrained   different     AdamW     64                4      10
# 9     w2v_pretrained   different     AdamW      8                3       5
# 189   ft_selftrained       equal     AdamW      8                4      10
# 195   w2v_pretrained   different     AdamW     64                2       5
# 133  w2v_selftrained       equal     AdamW      8                3      10
# 41    w2v_pretrained   different     AdamW      8                4      10
# 121  w2v_selftrained   different     AdamW      8                2      10
# 43    w2v_pretrained   different     AdamW      8                4      10
# 31    w2v_pretrained       equal     AdamW      8                2      10
# 217   w2v_pretrained   different     AdamW     64                2      10
# 21    w2v_pretrained       equal     AdamW      8                4       5
# 5     w2v_pretrained       equal     AdamW      8                2       5
# 129  w2v_selftrained   different     AdamW      8                3      10
# 221   w2v_pretrained       equal     AdamW     64                2      10
# 15    w2v_pretrained       equal     AdamW      8                3       5
# 29    w2v_pretrained       equal     AdamW      8                2      10
# 35    w2v_pretrained   different     AdamW      8                3      10
# 39    w2v_pretrained       equal     AdamW      8                3      10
# 47    w2v_pretrained       equal     AdamW      8                4      10
# 345   ft_selftrained   different     AdamW     64                3       5
# 37    w2v_pretrained       equal     AdamW      8                3      10
# 237   w2v_pretrained       equal     AdamW     64                4      10
# 45    w2v_pretrained       equal     AdamW      8                4      10
# 229   w2v_pretrained       equal     AdamW     64                3      10
# 24    w2v_pretrained   different       SGD      8                2      10
# 329  w2v_selftrained   different     AdamW     64                4      10
# 239   w2v_pretrained       equal     AdamW     64                4      10
# 25    w2v_pretrained   different     AdamW      8                2      10
# 165   ft_selftrained       equal     AdamW      8                4       5
# 172   ft_selftrained       equal       SGD      8                2      10
# 168   ft_selftrained   different       SGD      8                2      10
# 0     w2v_pretrained   different       SGD      8                2       5
# 28    w2v_pretrained       equal       SGD      8                2      10
# 1     w2v_pretrained   different     AdamW      8                2       5
# 91     ft_pretrained   different     AdamW      8                4      10
# 75     ft_pretrained   different     AdamW      8                2      10
# 267    ft_pretrained   different     AdamW     64                2      10
# 283    ft_pretrained   different     AdamW     64                4      10
# 271    ft_pretrained       equal     AdamW     64                2      10
# 257    ft_pretrained   different     AdamW     64                4       5
# 275    ft_pretrained   different     AdamW     64                3      10
# 255    ft_pretrained       equal     AdamW     64                3       5
# 95     ft_pretrained       equal     AdamW      8                4      10
# 247    ft_pretrained       equal     AdamW     64                2       5
# 87     ft_pretrained       equal     AdamW      8                3      10
# 265    ft_pretrained   different     AdamW     64                2      10
# 279    ft_pretrained       equal     AdamW     64                3      10
# 263    ft_pretrained       equal     AdamW     64                4       5
# 83     ft_pretrained   different     AdamW      8                3      10
# 277    ft_pretrained       equal     AdamW     64                3      10
# 281    ft_pretrained   different     AdamW     64                4      10
# 287    ft_pretrained       equal     AdamW     64                4      10
# 259    ft_pretrained   different     AdamW     64                4       5
# 51     ft_pretrained   different     AdamW      8                2       5
# 55     ft_pretrained       equal     AdamW      8                2       5
# 79     ft_pretrained       equal     AdamW      8                2      10
# 59     ft_pretrained   different     AdamW      8                3       5
# 249    ft_pretrained   different     AdamW     64                3       5
# 71     ft_pretrained       equal     AdamW      8                4       5
# 63     ft_pretrained       equal     AdamW      8                3       5
# 40    w2v_pretrained   different       SGD      8                4      10
# 20    w2v_pretrained       equal       SGD      8                4       5
# 19    w2v_pretrained   different     AdamW      8                4       5
# 18    w2v_pretrained   different       SGD      8                4       5
# 17    w2v_pretrained   different     AdamW      8                4       5
# 16    w2v_pretrained   different       SGD      8                4       5
# 14    w2v_pretrained       equal       SGD      8                3       5
# 13    w2v_pretrained       equal     AdamW      8                3       5
# 136  w2v_selftrained   different       SGD      8                4      10
# 12    w2v_pretrained       equal       SGD      8                3       5
# 10    w2v_pretrained   different       SGD      8                3       5
# 8     w2v_pretrained   different       SGD      8                3       5
# 26    w2v_pretrained   different       SGD      8                2      10
# 69     ft_pretrained       equal     AdamW      8                4       5
# 6     w2v_pretrained       equal       SGD      8                2       5
# 70     ft_pretrained       equal       SGD      8                4       5
# 72     ft_pretrained   different       SGD      8                2      10
# 73     ft_pretrained   different     AdamW      8                2      10
# 74     ft_pretrained   different       SGD      8                2      10
# 4     w2v_pretrained       equal       SGD      8                2       5
# 76     ft_pretrained       equal       SGD      8                2      10
# 2     w2v_pretrained   different       SGD      8                2       5
# 77     ft_pretrained       equal     AdamW      8                2      10
# 78     ft_pretrained       equal       SGD      8                2      10
# 22    w2v_pretrained       equal       SGD      8                4       5
# 30    w2v_pretrained       equal       SGD      8                2      10
# 42    w2v_pretrained   different       SGD      8                4      10
# 32    w2v_pretrained   different       SGD      8                3      10
# 44    w2v_pretrained       equal       SGD      8                4      10
# 46    w2v_pretrained       equal       SGD      8                4      10
# 48     ft_pretrained   different       SGD      8                2       5
# 49     ft_pretrained   different     AdamW      8                2       5
# 50     ft_pretrained   different       SGD      8                2       5
# 38    w2v_pretrained       equal       SGD      8                3      10
# 52     ft_pretrained       equal       SGD      8                2       5
# 53     ft_pretrained       equal     AdamW      8                2       5
# 54     ft_pretrained       equal       SGD      8                2       5
# 36    w2v_pretrained       equal       SGD      8                3      10
# 56     ft_pretrained   different       SGD      8                3       5
# 57     ft_pretrained   different     AdamW      8                3       5
# 58     ft_pretrained   different       SGD      8                3       5
# 80     ft_pretrained   different       SGD      8                3      10
# 61     ft_pretrained       equal     AdamW      8                3       5
# 62     ft_pretrained       equal       SGD      8                3       5
# 64     ft_pretrained   different       SGD      8                4       5
# 65     ft_pretrained   different     AdamW      8                4       5
# 66     ft_pretrained   different       SGD      8                4       5
# 67     ft_pretrained   different     AdamW      8                4       5
# 68     ft_pretrained       equal       SGD      8                4       5
# 34    w2v_pretrained   different       SGD      8                3      10
# 33    w2v_pretrained   different     AdamW      8                3      10
# 60     ft_pretrained       equal       SGD      8                3       5
# 134  w2v_selftrained       equal       SGD      8                3      10
# 156   ft_selftrained       equal       SGD      8                3       5
# 92     ft_pretrained       equal       SGD      8                4      10
# 178   ft_selftrained   different       SGD      8                3      10
# 128  w2v_selftrained   different       SGD      8                3      10
# 166   ft_selftrained       equal       SGD      8                4       5
# 89     ft_pretrained   different     AdamW      8                4      10
# 152   ft_selftrained   different       SGD      8                3       5
# 98   w2v_selftrained   different       SGD      8                2       5
# 153   ft_selftrained   different     AdamW      8                3       5
# 90     ft_pretrained   different       SGD      8                4      10
# 154   ft_selftrained   different       SGD      8                3       5
# 180   ft_selftrained       equal       SGD      8                3      10
# 126  w2v_selftrained       equal       SGD      8                2      10
# 114  w2v_selftrained   different       SGD      8                4       5
# 170   ft_selftrained   different       SGD      8                2      10
# 97   w2v_selftrained   different     AdamW      8                2       5
# 122  w2v_selftrained   different       SGD      8                2      10
# 81     ft_pretrained   different     AdamW      8                3      10
# 158   ft_selftrained       equal       SGD      8                3       5
# 93     ft_pretrained       equal     AdamW      8                4      10
# 182   ft_selftrained       equal       SGD      8                3      10
# 118  w2v_selftrained       equal       SGD      8                4       5
# 164   ft_selftrained       equal       SGD      8                4       5
# 190   ft_selftrained       equal       SGD      8                4      10
# 160   ft_selftrained   different       SGD      8                4       5
# 94     ft_pretrained       equal       SGD      8                4      10
# 96   w2v_selftrained   different       SGD      8                2       5
# 188   ft_selftrained       equal       SGD      8                4      10
# 116  w2v_selftrained       equal       SGD      8                4       5
# 186   ft_selftrained   different       SGD      8                4      10
# 185   ft_selftrained   different     AdamW      8                4      10
# 162   ft_selftrained   different       SGD      8                4       5
# 163   ft_selftrained   different     AdamW      8                4       5
# 150   ft_selftrained       equal       SGD      8                2       5
# 130  w2v_selftrained   different       SGD      8                3      10
# 174   ft_selftrained       equal       SGD      8                2      10
# 106  w2v_selftrained   different       SGD      8                3       5
# 137  w2v_selftrained   different     AdamW      8                4      10
# 108  w2v_selftrained       equal       SGD      8                3       5
# 82     ft_pretrained   different       SGD      8                3      10
# 138  w2v_selftrained   different       SGD      8                4      10
# 104  w2v_selftrained   different       SGD      8                3       5
# 139  w2v_selftrained   different     AdamW      8                4      10
# 140  w2v_selftrained       equal       SGD      8                4      10
# 84     ft_pretrained       equal       SGD      8                3      10
# 102  w2v_selftrained       equal       SGD      8                2       5
# 132  w2v_selftrained       equal       SGD      8                3      10
# 110  w2v_selftrained       equal       SGD      8                3       5
# 85     ft_pretrained       equal     AdamW      8                3      10
# 177   ft_selftrained   different     AdamW      8                3      10
# 142  w2v_selftrained       equal       SGD      8                4      10
# 131  w2v_selftrained   different     AdamW      8                3      10
# 112  w2v_selftrained   different       SGD      8                4       5
# 88     ft_pretrained   different       SGD      8                4      10
# 148   ft_selftrained       equal       SGD      8                2       5
# 147   ft_selftrained   different     AdamW      8                2       5
# 176   ft_selftrained   different       SGD      8                3      10
# 146   ft_selftrained   different       SGD      8                2       5
# 86     ft_pretrained       equal       SGD      8                3      10
# 184   ft_selftrained   different       SGD      8                4      10
# 145   ft_selftrained   different     AdamW      8                2       5
# 100  w2v_selftrained       equal       SGD      8                2       5
# 144   ft_selftrained   different       SGD      8                2       5
# 243    ft_pretrained   different     AdamW     64                2       5
# 324  w2v_selftrained       equal       SGD     64                3      10
# 322  w2v_selftrained   different       SGD     64                3      10
# 328  w2v_selftrained   different       SGD     64                4      10
# 320  w2v_selftrained   different       SGD     64                3      10
# 326  w2v_selftrained       equal       SGD     64                3      10
# 318  w2v_selftrained       equal       SGD     64                2      10
# 216   w2v_pretrained   different       SGD     64                2      10
# 330  w2v_selftrained   different       SGD     64                4      10
# 332  w2v_selftrained       equal       SGD     64                4      10
# 382   ft_selftrained       equal       SGD     64                4      10
# 380   ft_selftrained       equal       SGD     64                4      10
# 378   ft_selftrained   different       SGD     64                4      10
# 376   ft_selftrained   different       SGD     64                4      10
# 374   ft_selftrained       equal       SGD     64                3      10
# 372   ft_selftrained       equal       SGD     64                3      10
# 370   ft_selftrained   different       SGD     64                3      10
# 368   ft_selftrained   different       SGD     64                3      10
# 366   ft_selftrained       equal       SGD     64                2      10
# 364   ft_selftrained       equal       SGD     64                2      10
# 362   ft_selftrained   different       SGD     64                2      10
# 360   ft_selftrained   different       SGD     64                2      10
# 358   ft_selftrained       equal       SGD     64                4       5
# 356   ft_selftrained       equal       SGD     64                4       5
# 354   ft_selftrained   different       SGD     64                4       5
# 352   ft_selftrained   different       SGD     64                4       5
# 350   ft_selftrained       equal       SGD     64                3       5
# 348   ft_selftrained       equal       SGD     64                3       5
# 346   ft_selftrained   different       SGD     64                3       5
# 344   ft_selftrained   different       SGD     64                3       5
# 342   ft_selftrained       equal       SGD     64                2       5
# 340   ft_selftrained       equal       SGD     64                2       5
# 338   ft_selftrained   different       SGD     64                2       5
# 336   ft_selftrained   different       SGD     64                2       5
# 334  w2v_selftrained       equal       SGD     64                4      10
# 316  w2v_selftrained       equal       SGD     64                2      10
# 300  w2v_selftrained       equal       SGD     64                3       5
# 314  w2v_selftrained   different       SGD     64                2      10
# 258    ft_pretrained   different       SGD     64                4       5
# 256    ft_pretrained   different       SGD     64                4       5
# 254    ft_pretrained       equal       SGD     64                3       5
# 253    ft_pretrained       equal     AdamW     64                3       5
# 252    ft_pretrained       equal       SGD     64                3       5
# 251    ft_pretrained   different     AdamW     64                3       5
# 250    ft_pretrained   different       SGD     64                3       5
# 200   w2v_pretrained   different       SGD     64                3       5
# 248    ft_pretrained   different       SGD     64                3       5
# 246    ft_pretrained       equal       SGD     64                2       5
# 245    ft_pretrained       equal     AdamW     64                2       5
# 244    ft_pretrained       equal       SGD     64                2       5
# 241    ft_pretrained   different     AdamW     64                2       5
# 240    ft_pretrained   different       SGD     64                2       5
# 238   w2v_pretrained       equal       SGD     64                4      10
# 204   w2v_pretrained       equal       SGD     64                3       5
# 236   w2v_pretrained       equal       SGD     64                4      10
# 234   w2v_pretrained   different       SGD     64                4      10
# 206   w2v_pretrained       equal       SGD     64                3       5
# 232   w2v_pretrained   different       SGD     64                4      10
# 230   w2v_pretrained       equal       SGD     64                3      10
# 208   w2v_pretrained   different       SGD     64                4       5
# 228   w2v_pretrained       equal       SGD     64                3      10
# 226   w2v_pretrained   different       SGD     64                3      10
# 210   w2v_pretrained   different       SGD     64                4       5
# 224   w2v_pretrained   different       SGD     64                3      10
# 212   w2v_pretrained       equal       SGD     64                4       5
# 222   w2v_pretrained       equal       SGD     64                2      10
# 220   w2v_pretrained       equal       SGD     64                2      10
# 214   w2v_pretrained       equal       SGD     64                4       5
# 312  w2v_selftrained   different       SGD     64                2      10
# 198   w2v_pretrained       equal       SGD     64                2       5
# 260    ft_pretrained       equal       SGD     64                4       5
# 261    ft_pretrained       equal     AdamW     64                4       5
# 310  w2v_selftrained       equal       SGD     64                4       5
# 308  w2v_selftrained       equal       SGD     64                4       5
# 306  w2v_selftrained   different       SGD     64                4       5
# 304  w2v_selftrained   different       SGD     64                4       5
# 302  w2v_selftrained       equal       SGD     64                3       5
# 298  w2v_selftrained   different       SGD     64                3       5
# 296  w2v_selftrained   different       SGD     64                3       5
# 294  w2v_selftrained       equal       SGD     64                2       5
# 292  w2v_selftrained       equal       SGD     64                2       5
# 288  w2v_selftrained   different       SGD     64                2       5
# 286    ft_pretrained       equal       SGD     64                4      10
# 285    ft_pretrained       equal     AdamW     64                4      10
# 284    ft_pretrained       equal       SGD     64                4      10
# 280    ft_pretrained   different       SGD     64                4      10
# 270    ft_pretrained       equal       SGD     64                2      10
# 278    ft_pretrained       equal       SGD     64                3      10
# 262    ft_pretrained       equal       SGD     64                4       5
# 196   w2v_pretrained       equal       SGD     64                2       5
# 264    ft_pretrained   different       SGD     64                2      10
# 266    ft_pretrained   different       SGD     64                2      10
# 268    ft_pretrained       equal       SGD     64                2      10
# 269    ft_pretrained       equal     AdamW     64                2      10
# 192   w2v_pretrained   different       SGD     64                2       5
# 272    ft_pretrained   different       SGD     64                3      10
# 273    ft_pretrained   different     AdamW     64                3      10
# 274    ft_pretrained   different       SGD     64                3      10
# 276    ft_pretrained       equal       SGD     64                3      10
# 290  w2v_selftrained   different       SGD     64                2       5
# 194   w2v_pretrained   different       SGD     64                2       5
# 242    ft_pretrained   different       SGD     64                2       5
# 282    ft_pretrained   different       SGD     64                4      10
# 218   w2v_pretrained   different       SGD     64                2      10
# 202   w2v_pretrained   different       SGD     64                3       5
#
#      Learning rate Activation function  F1-train  F1-val  F1-test
# 367          0.001                relu    0.7002  0.6935   0.6400
# 171          0.001                relu    0.7255  0.6912   0.5671
# 351          0.001                relu    0.6943  0.6876   0.6000
# 175          0.001                relu    0.7269  0.6869   0.6303
# 151          0.001                relu    0.6934  0.6851   0.6395
# 355          0.001                relu    0.6871  0.6845   0.6000
# 155          0.001                relu    0.7011  0.6840   0.5972
# 347          0.001                relu    0.6870  0.6840   0.5805
# 339          0.001                relu    0.6898  0.6840   0.6006
# 363          0.001                relu    0.6946  0.6834   0.6604
# 343          0.001                relu    0.6877  0.6828   0.6000
# 337          0.010                relu    0.6995  0.6825   0.5900
# 371          0.001                relu    0.7028  0.6821   0.6006
# 379          0.001                relu    0.7503  0.6817   0.5805
# 103          0.001                relu    0.7012  0.6815   0.6997
# 361          0.010                relu    0.7237  0.6802   0.5600
# 159          0.001                relu    0.7113  0.6795   0.5816
# 327          0.001                relu    0.7430  0.6793   0.6604
# 303          0.001                relu    0.7064  0.6793   0.6994
# 349          0.010                relu    0.7059  0.6791   0.6205
# 179          0.001                relu    0.7498  0.6788   0.5998
# 123          0.001                relu    0.7324  0.6784   0.7186
# 149          0.010                relu    0.6872  0.6778   0.5773
# 341          0.010                relu    0.7016  0.6776   0.5600
# 375          0.001                relu    0.7392  0.6776   0.6784
# 381          0.010                relu    0.7494  0.6774   0.6400
# 307          0.001                relu    0.7067  0.6773   0.6994
# 321          0.010                relu    0.7738  0.6755   0.6784
# 187          0.001                relu    0.7811  0.6755   0.5493
# 373          0.010                relu    0.7393  0.6752   0.5805
# 359          0.001                relu    0.7197  0.6750   0.6129
# 377          0.010                relu    0.7636  0.6750   0.5579
# 383          0.001                relu    0.7823  0.6748   0.6129
# 289          0.010                relu    0.6931  0.6746   0.7004
# 319          0.001                relu    0.7122  0.6746   0.6400
# 99           0.001                relu    0.6945  0.6744   0.6947
# 293          0.010                relu    0.7092  0.6743   0.6974
# 353          0.010                relu    0.6991  0.6735   0.6092
# 299          0.001                relu    0.6944  0.6734   0.6974
# 169          0.010                relu    0.6997  0.6730   0.6786
# 317          0.010                relu    0.7366  0.6729   0.6400
# 295          0.001                relu    0.6882  0.6728   0.7395
# 167          0.001                relu    0.7300  0.6728   0.5831
# 107          0.001                relu    0.7116  0.6728   0.6967
# 191          0.001                relu    0.7912  0.6725   0.6085
# 291          0.001                relu    0.6868  0.6724   0.7186
# 161          0.010                relu    0.6842  0.6718   0.5833
# 143          0.001                relu    0.8050  0.6714   0.6591
# 157          0.010                relu    0.6884  0.6712   0.6250
# 365          0.010                relu    0.7331  0.6700   0.6192
# 101          0.010                relu    0.6940  0.6697   0.6544
# 117          0.010                relu    0.6918  0.6691   0.6695
# 111          0.001                relu    0.7267  0.6688   0.6713
# 323          0.001                relu    0.7379  0.6685   0.6205
# 315          0.001                relu    0.6938  0.6685   0.6604
# 183          0.001                relu    0.7775  0.6684   0.5509
# 297          0.010                relu    0.7080  0.6682   0.6571
# 313          0.010                relu    0.7355  0.6679   0.7004
# 369          0.010                relu    0.7214  0.6677   0.6353
# 113          0.010                relu    0.7056  0.6676   0.6890
# 141          0.010                relu    0.7271  0.6675   0.7090
# 173          0.010                relu    0.6974  0.6672   0.5561
# 331          0.001                relu    0.7656  0.6666   0.6593
# 109          0.010                relu    0.6957  0.6660   0.6820
# 105          0.010                relu    0.6960  0.6655   0.7519
# 135          0.001                relu    0.7869  0.6655   0.7230
# 305          0.010                relu    0.7210  0.6652   0.6784
# 125          0.010                relu    0.7080  0.6639   0.7209
# 201          0.010                relu    0.6802  0.6637   0.7403
# 197          0.010                relu    0.6776  0.6636   0.6593
# 309          0.010                relu    0.7207  0.6628   0.7540
# 205          0.010                relu    0.6818  0.6625   0.7600
# 127          0.001                relu    0.7436  0.6624   0.5288
# 311          0.001                relu    0.7299  0.6624   0.7163
# 223          0.001                relu    0.6949  0.6617   0.7004
# 325          0.010                relu    0.7632  0.6608   0.6903
# 357          0.010                relu    0.7068  0.6607   0.6253
# 231          0.001                relu    0.7078  0.6605   0.6406
# 119          0.001                relu    0.7538  0.6604   0.6479
# 301          0.010                relu    0.7193  0.6602   0.6593
# 207          0.001                relu    0.6758  0.6601   0.6406
# 203          0.001                relu    0.6730  0.6597   0.6604
# 333          0.010                relu    0.7831  0.6594   0.6400
# 199          0.001                relu    0.6705  0.6590   0.6800
# 215          0.001                relu    0.6951  0.6589   0.7200
# 27           0.001                relu    0.6963  0.6587   0.6641
# 211          0.001                relu    0.6777  0.6584   0.6800
# 124          0.010                relu    0.6709  0.6576   0.6592
# 335          0.001                relu    0.8023  0.6574   0.6800
# 181          0.010                relu    0.7141  0.6573   0.5462
# 227          0.001                relu    0.6951  0.6569   0.6604
# 213          0.010                relu    0.6833  0.6568   0.6805
# 235          0.001                relu    0.7132  0.6566   0.6192
# 3            0.001                relu    0.6725  0.6566   0.6432
# 219          0.001                relu    0.6831  0.6565   0.6604
# 120          0.010                relu    0.6706  0.6562   0.6992
# 7            0.001                relu    0.6793  0.6558   0.6432
# 11           0.001                relu    0.6849  0.6555   0.6585
# 193          0.010                relu    0.6784  0.6553   0.6604
# 115          0.001                relu    0.4614  0.6550   0.6792
# 23           0.001                relu    0.6957  0.6550   0.6432
# 225          0.010                relu    0.7199  0.6550   0.7004
# 209          0.010                relu    0.6793  0.6549   0.7187
# 233          0.010                relu    0.7315  0.6536   0.7186
# 9            0.010                relu    0.6635  0.6529   0.6305
# 189          0.010                relu    0.7054  0.6529   0.5300
# 195          0.001                relu    0.6693  0.6528   0.6994
# 133          0.010                relu    0.7210  0.6525   0.6997
# 41           0.010                relu    0.6875  0.6523   0.7069
# 121          0.010                relu    0.7044  0.6521   0.7370
# 43           0.001                relu    0.7406  0.6519   0.6765
# 31           0.001                relu    0.7150  0.6516   0.6623
# 217          0.010                relu    0.7086  0.6513   0.6974
# 21           0.010                relu    0.6667  0.6495   0.6635
# 5            0.010                relu    0.6640  0.6494   0.7409
# 129          0.010                relu    0.7231  0.6473   0.7039
# 221          0.010                relu    0.7094  0.6471   0.6400
# 15           0.001                relu    0.6884  0.6469   0.6432
# 29           0.010                relu    0.6944  0.6469   0.6291
# 35           0.001                relu    0.7413  0.6467   0.7576
# 39           0.001                relu    0.7348  0.6465   0.6051
# 47           0.001                relu    0.7520  0.6449   0.6828
# 345          0.010                relu    0.6881  0.6446   0.5924
# 37           0.010                relu    0.6925  0.6433   0.6480
# 237          0.010                relu    0.7182  0.6430   0.7403
# 45           0.010                relu    0.6933  0.6405   0.6778
# 229          0.010                relu    0.7150  0.6403   0.6400
# 24           0.010                relu    0.6299  0.6400   0.7000
# 329          0.010                relu    0.7764  0.6388   0.6383
# 239          0.001                relu    0.7780  0.6384   0.6571
# 25           0.010                relu    0.6771  0.6361   0.7307
# 165          0.010                relu    0.6834  0.6359   0.5538
# 172          0.010                relu    0.6732  0.6323   0.5299
# 168          0.010                relu    0.6694  0.6290   0.5440
# 0            0.010                relu    0.5238  0.6268   0.6634
# 28           0.010                relu    0.5284  0.6255   0.6445
# 1            0.010                relu    0.6631  0.6071   0.6478
# 91           0.001                relu    0.5978  0.5943   0.4916
# 75           0.001                relu    0.6010  0.5922   0.5793
# 267          0.001                relu    0.6021  0.5884   0.5169
# 283          0.001                relu    0.6005  0.5874   0.5542
# 271          0.001                relu    0.6012  0.5869   0.5421
# 257          0.010                relu    0.5710  0.5858   0.4908
# 275          0.001                relu    0.6069  0.5846   0.5314
# 255          0.001                relu    0.5832  0.5840   0.4484
# 95           0.001                relu    0.5982  0.5828   0.4784
# 247          0.001                relu    0.5782  0.5823   0.4637
# 87           0.001                relu    0.5912  0.5811   0.5689
# 265          0.010                relu    0.5707  0.5799   0.5251
# 279          0.001                relu    0.6004  0.5795   0.4789
# 263          0.001                relu    0.5771  0.5767   0.5333
# 83           0.001                relu    0.6026  0.5760   0.5564
# 277          0.010                relu    0.5684  0.5685   0.4484
# 281          0.010                relu    0.5873  0.5673   0.4637
# 287          0.001                relu    0.5947  0.5664   0.4644
# 259          0.001                relu    0.5807  0.5651   0.4637
# 51           0.001                relu    0.5780  0.5575   0.5302
# 55           0.001                relu    0.5799  0.5554   0.5464
# 79           0.001                relu    0.5988  0.5450   0.5417
# 59           0.001                relu    0.5818  0.5418   0.5460
# 249          0.010                relu    0.5713  0.5409   0.4644
# 71           0.001                relu    0.5710  0.5270   0.4663
# 63           0.001                relu    0.5806  0.5239   0.5034
# 40           0.010                relu    0.3898  0.3887   0.3961
# 20           0.010                relu    0.3898  0.3887   0.3961
# 19           0.001                relu    0.3898  0.3887   0.3961
# 18           0.001                relu    0.3898  0.3887   0.3961
# 17           0.010                relu    0.3869  0.3887   0.3961
# 16           0.010                relu    0.3898  0.3887   0.3961
# 14           0.001                relu    0.3898  0.3887   0.3961
# 13           0.010                relu    0.3869  0.3887   0.3961
# 136          0.010                relu    0.3898  0.3887   0.3961
# 12           0.010                relu    0.3898  0.3887   0.3961
# 10           0.001                relu    0.3898  0.3887   0.3961
# 8            0.010                relu    0.3898  0.3887   0.3961
# 26           0.001                relu    0.3898  0.3887   0.3961
# 69           0.010                relu    0.3869  0.3887   0.3961
# 6            0.001                relu    0.3898  0.3887   0.3961
# 70           0.001                relu    0.3898  0.3887   0.3961
# 72           0.010                relu    0.3898  0.3887   0.3961
# 73           0.010                relu    0.3869  0.3887   0.3961
# 74           0.001                relu    0.3898  0.3887   0.3961
# 4            0.010                relu    0.3898  0.3887   0.3961
# 76           0.010                relu    0.3898  0.3887   0.3961
# 2            0.001                relu    0.3898  0.3887   0.3961
# 77           0.010                relu    0.3869  0.3887   0.3961
# 78           0.001                relu    0.3898  0.3887   0.3961
# 22           0.001                relu    0.3898  0.3887   0.3961
# 30           0.001                relu    0.3898  0.3887   0.3961
# 42           0.001                relu    0.3898  0.3887   0.3961
# 32           0.010                relu    0.3898  0.3887   0.3961
# 44           0.010                relu    0.3898  0.3887   0.3961
# 46           0.001                relu    0.3898  0.3887   0.3961
# 48           0.010                relu    0.3898  0.3887   0.3961
# 49           0.010                relu    0.3869  0.3887   0.3961
# 50           0.001                relu    0.3898  0.3887   0.3961
# 38           0.001                relu    0.3898  0.3887   0.3961
# 52           0.010                relu    0.3898  0.3887   0.3961
# 53           0.010                relu    0.3869  0.3887   0.3961
# 54           0.001                relu    0.3898  0.3887   0.3961
# 36           0.010                relu    0.3905  0.3887   0.3961
# 56           0.010                relu    0.3898  0.3887   0.3961
# 57           0.010                relu    0.3869  0.3887   0.3961
# 58           0.001                relu    0.3898  0.3887   0.3961
# 80           0.010                relu    0.3898  0.3887   0.3961
# 61           0.010                relu    0.3869  0.3887   0.3961
# 62           0.001                relu    0.3898  0.3887   0.3961
# 64           0.010                relu    0.3898  0.3887   0.3961
# 65           0.010                relu    0.3869  0.3887   0.3961
# 66           0.001                relu    0.3898  0.3887   0.3961
# 67           0.001                relu    0.3898  0.3887   0.3961
# 68           0.010                relu    0.3898  0.3887   0.3961
# 34           0.001                relu    0.3898  0.3887   0.3961
# 33           0.010                relu    0.3869  0.3887   0.3961
# 60           0.010                relu    0.3898  0.3887   0.3961
# 134          0.001                relu    0.3898  0.3887   0.3961
# 156          0.010                relu    0.3898  0.3887   0.3961
# 92           0.010                relu    0.3898  0.3887   0.3961
# 178          0.001                relu    0.3898  0.3887   0.3961
# 128          0.010                relu    0.3898  0.3887   0.3961
# 166          0.001                relu    0.3898  0.3887   0.3961
# 89           0.010                relu    0.3869  0.3887   0.3961
# 152          0.010                relu    0.3898  0.3887   0.3961
# 98           0.001                relu    0.3898  0.3887   0.3961
# 153          0.010                relu    0.3865  0.3887   0.3961
# 90           0.001                relu    0.3898  0.3887   0.3961
# 154          0.001                relu    0.3898  0.3887   0.3961
# 180          0.010                relu    0.3898  0.3887   0.3961
# 126          0.001                relu    0.3898  0.3887   0.3961
# 114          0.001                relu    0.3898  0.3887   0.3961
# 170          0.001                relu    0.3898  0.3887   0.3961
# 97           0.010                relu    0.3869  0.3887   0.3961
# 122          0.001                relu    0.3898  0.3887   0.3961
# 81           0.010                relu    0.3869  0.3887   0.3961
# 158          0.001                relu    0.3898  0.3887   0.3961
# 93           0.010                relu    0.3869  0.3887   0.3961
# 182          0.001                relu    0.3898  0.3887   0.3961
# 118          0.001                relu    0.3898  0.3887   0.3961
# 164          0.010                relu    0.3898  0.3887   0.3961
# 190          0.001                relu    0.3898  0.3887   0.3961
# 160          0.010                relu    0.3898  0.3887   0.3961
# 94           0.001                relu    0.3898  0.3887   0.3961
# 96           0.010                relu    0.3898  0.3887   0.3961
# 188          0.010                relu    0.3898  0.3887   0.3961
# 116          0.010                relu    0.3898  0.3887   0.3961
# 186          0.001                relu    0.3898  0.3887   0.3961
# 185          0.010                relu    0.3869  0.3887   0.3961
# 162          0.001                relu    0.3898  0.3887   0.3961
# 163          0.001                relu    0.3898  0.3887   0.3961
# 150          0.001                relu    0.3898  0.3887   0.3961
# 130          0.001                relu    0.3898  0.3887   0.3961
# 174          0.001                relu    0.3898  0.3887   0.3961
# 106          0.001                relu    0.3898  0.3887   0.3961
# 137          0.010                relu    0.3869  0.3887   0.3961
# 108          0.010                relu    0.3898  0.3887   0.3961
# 82           0.001                relu    0.3898  0.3887   0.3961
# 138          0.001                relu    0.3898  0.3887   0.3961
# 104          0.010                relu    0.3898  0.3887   0.3961
# 139          0.001                relu    0.3898  0.3887   0.3961
# 140          0.010                relu    0.3898  0.3887   0.3961
# 84           0.010                relu    0.3898  0.3887   0.3961
# 102          0.001                relu    0.3898  0.3887   0.3961
# 132          0.010                relu    0.3900  0.3887   0.3961
# 110          0.001                relu    0.3898  0.3887   0.3961
# 85           0.010                relu    0.3869  0.3887   0.3961
# 177          0.010                relu    0.3869  0.3887   0.3961
# 142          0.001                relu    0.3898  0.3887   0.3961
# 131          0.001                relu    0.3898  0.3887   0.3961
# 112          0.010                relu    0.3898  0.3887   0.3961
# 88           0.010                relu    0.3898  0.3887   0.3961
# 148          0.010                relu    0.3898  0.3887   0.3961
# 147          0.001                relu    0.3898  0.3887   0.3961
# 176          0.010                relu    0.3948  0.3887   0.3961
# 146          0.001                relu    0.3898  0.3887   0.3961
# 86           0.001                relu    0.3898  0.3887   0.3961
# 184          0.010                relu    0.3898  0.3887   0.3961
# 145          0.010                relu    0.3869  0.3887   0.3961
# 100          0.010                relu    0.3898  0.3887   0.3961
# 144          0.010                relu    0.3898  0.3887   0.3961
# 243          0.001                relu    0.3763  0.3781   0.3695
# 324          0.010                relu    0.3735  0.3732   0.3787
# 322          0.001                relu    0.3735  0.3732   0.3787
# 328          0.010                relu    0.3735  0.3732   0.3787
# 320          0.010                relu    0.3735  0.3732   0.3787
# 326          0.001                relu    0.3735  0.3732   0.3787
# 318          0.001                relu    0.3735  0.3732   0.3787
# 216          0.010                relu    0.3735  0.3732   0.3787
# 330          0.001                relu    0.3735  0.3732   0.3787
# 332          0.010                relu    0.3735  0.3732   0.3787
# 382          0.001                relu    0.3735  0.3732   0.3787
# 380          0.010                relu    0.3735  0.3732   0.3787
# 378          0.001                relu    0.3735  0.3732   0.3787
# 376          0.010                relu    0.3735  0.3732   0.3787
# 374          0.001                relu    0.3735  0.3732   0.3787
# 372          0.010                relu    0.3735  0.3732   0.3787
# 370          0.001                relu    0.3735  0.3732   0.3787
# 368          0.010                relu    0.3735  0.3732   0.3787
# 366          0.001                relu    0.3735  0.3732   0.3787
# 364          0.010                relu    0.3735  0.3732   0.3787
# 362          0.001                relu    0.3735  0.3732   0.3787
# 360          0.010                relu    0.3735  0.3732   0.3787
# 358          0.001                relu    0.3735  0.3732   0.3787
# 356          0.010                relu    0.3735  0.3732   0.3787
# 354          0.001                relu    0.3735  0.3732   0.3787
# 352          0.010                relu    0.3735  0.3732   0.3787
# 350          0.001                relu    0.3735  0.3732   0.3787
# 348          0.010                relu    0.3735  0.3732   0.3787
# 346          0.001                relu    0.3592  0.3732   0.3787
# 344          0.010                relu    0.3735  0.3732   0.3787
# 342          0.001                relu    0.3735  0.3732   0.3787
# 340          0.010                relu    0.3735  0.3732   0.3787
# 338          0.001                relu    0.3735  0.3732   0.3787
# 336          0.010                relu    0.3735  0.3732   0.3787
# 334          0.001                relu    0.3735  0.3732   0.3787
# 316          0.010                relu    0.3735  0.3732   0.3787
# 300          0.010                relu    0.3735  0.3732   0.3787
# 314          0.001                relu    0.3735  0.3732   0.3787
# 258          0.001                relu    0.3735  0.3732   0.3787
# 256          0.010                relu    0.3735  0.3732   0.3787
# 254          0.001                relu    0.3735  0.3732   0.3787
# 253          0.010                relu    0.3735  0.3732   0.3787
# 252          0.010                relu    0.3735  0.3732   0.3787
# 251          0.001                relu    0.3735  0.3732   0.3787
# 250          0.001                relu    0.3735  0.3732   0.3787
# 200          0.010                relu    0.3735  0.3732   0.3787
# 248          0.010                relu    0.3735  0.3732   0.3787
# 246          0.001                relu    0.3735  0.3732   0.3787
# 245          0.010                relu    0.3735  0.3732   0.3787
# 244          0.010                relu    0.3735  0.3732   0.3787
# 241          0.010                relu    0.3735  0.3732   0.3787
# 240          0.010                relu    0.3735  0.3732   0.3787
# 238          0.001                relu    0.3735  0.3732   0.3787
# 204          0.010                relu    0.3735  0.3732   0.3787
# 236          0.010                relu    0.3735  0.3732   0.3787
# 234          0.001                relu    0.3735  0.3732   0.3787
# 206          0.001                relu    0.3735  0.3732   0.3787
# 232          0.010                relu    0.3735  0.3732   0.3787
# 230          0.001                relu    0.3735  0.3732   0.3787
# 208          0.010                relu    0.3735  0.3732   0.3787
# 228          0.010                relu    0.3735  0.3732   0.3787
# 226          0.001                relu    0.3735  0.3732   0.3787
# 210          0.001                relu    0.3735  0.3732   0.3787
# 224          0.010                relu    0.3735  0.3732   0.3787
# 212          0.010                relu    0.3735  0.3732   0.3787
# 222          0.001                relu    0.3735  0.3732   0.3787
# 220          0.010                relu    0.3735  0.3732   0.3787
# 214          0.001                relu    0.3735  0.3732   0.3787
# 312          0.010                relu    0.3735  0.3732   0.3787
# 198          0.001                relu    0.3735  0.3732   0.3787
# 260          0.010                relu    0.3735  0.3732   0.3787
# 261          0.010                relu    0.3735  0.3732   0.3787
# 310          0.001                relu    0.3735  0.3732   0.3787
# 308          0.010                relu    0.3735  0.3732   0.3787
# 306          0.001                relu    0.3735  0.3732   0.3787
# 304          0.010                relu    0.3735  0.3732   0.3787
# 302          0.001                relu    0.3735  0.3732   0.3787
# 298          0.001                relu    0.3735  0.3732   0.3787
# 296          0.010                relu    0.3735  0.3732   0.3787
# 294          0.001                relu    0.3735  0.3732   0.3787
# 292          0.010                relu    0.3735  0.3732   0.3787
# 288          0.010                relu    0.3735  0.3732   0.3787
# 286          0.001                relu    0.3735  0.3732   0.3787
# 285          0.010                relu    0.3735  0.3732   0.3787
# 284          0.010                relu    0.3735  0.3732   0.3787
# 280          0.010                relu    0.3735  0.3732   0.3787
# 270          0.001                relu    0.3735  0.3732   0.3787
# 278          0.001                relu    0.3735  0.3732   0.3787
# 262          0.001                relu    0.3735  0.3732   0.3787
# 196          0.010                relu    0.3735  0.3732   0.3787
# 264          0.010                relu    0.3735  0.3732   0.3787
# 266          0.001                relu    0.3735  0.3732   0.3787
# 268          0.010                relu    0.3735  0.3732   0.3787
# 269          0.010                relu    0.3735  0.3732   0.3787
# 192          0.010                relu    0.3735  0.3732   0.3787
# 272          0.010                relu    0.3735  0.3732   0.3787
# 273          0.010                relu    0.3735  0.3732   0.3787
# 274          0.001                relu    0.3735  0.3732   0.3787
# 276          0.010                relu    0.3735  0.3732   0.3787
# 290          0.001                relu    0.2991  0.3007   0.2899
# 194          0.001                relu    0.2991  0.3007   0.2899
# 242          0.001                relu    0.2991  0.3007   0.2899
# 282          0.001                relu    0.2991  0.3007   0.2899
# 218          0.001                relu    0.2991  0.3007   0.2899
# 202          0.001                relu    0.2991  0.3007   0.2899

# %% [markdown]
# # Выводы

# %% [markdown]
# Эксперименты показали высокую точность нейросетей. Лучший результат был достигнут на самостоятельно обученной FastText модели на 4 слойной сети с одинаковыми слоями по 64 нейрона в каждом с показателем f1-weighted = 0.84. Обучение выполнялось с batch_size = 1, SDG и 10 эпохах. В целом, модели Word2Vec показали себя более устойчивыми к обучаемости и в среднем результат показан получше, чем у FastText.

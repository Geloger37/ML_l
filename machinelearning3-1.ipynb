# %% [markdown]
# # Начальная инициализация

# %%
import datetime
print(datetime.datetime.now().strftime('%d-%B-%Y %H:%M:%S'))
# Out:
# 26-May-2023 18:38:09

# %%
# Подключение библиотек

# !pip install torch torchvision torchaudio
# !pip install lightning
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data as data_utils
import lightning.pytorch as pl
import lightning as L

# !pip install scikit-learn
from sklearn.model_selection import ParameterGrid

import torch.optim as optim
# !pip install pandas
import pandas as pd
import numpy as np


import os
import random

# %%
# Подключение вычислений на видеокарту, если доступна
if torch.cuda.is_available():
    dev = "cuda:0"
else:
    dev = "cpu"
device = torch.device(dev)
print(device)
# Out:
# cuda:0

# %%
cpu_count = os.cpu_count()

num_workers = cpu_count if device == torch.device("cpu") else 0
num_workers, cpu_count
# Out:
# (0, 4)

# %%
random_state = 42

torch.use_deterministic_algorithms(True)

# %env CUBLAS_WORKSPACE_CONFIG=:4096:8
# %env PYTHONHASHSEED=42

def set_random_state(random_state):
    torch.manual_seed(random_state)
    random.seed(random_state)
    np.random.seed(random_state)

    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(random_state)
        torch.cuda.manual_seed(random_state)

        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False
        
set_random_state(random_state)

pl.seed_everything(random_state, workers=True)
# Out:
# env: CUBLAS_WORKSPACE_CONFIG=:4096:8
# env: PYTHONHASHSEED=42
# Global seed set to 42
# 42

# %%
print(datetime.datetime.now().strftime('%d-%B-%Y %H:%M:%S'))
# Out:
# 26-May-2023 18:38:14

# %% [markdown]
# # Обучение нейронных сетей

# %%
import pickle
PATH = 'dumps/'
# with open(PATH + 'X_train_ft_pre_trained.pkl', mode='rb') as file:
    # X_train_ft_pre_trained = pickle.load(file)

# with open(PATH + 'X_train_w2v_pre_trained.pkl', mode='rb') as file:
    # X_train_w2v_pre_trained = pickle.load(file)

# with open(PATH + 'X_test_w2v_pre_trained.pkl', mode='rb') as file:
    # X_test_w2v_pre_trained = pickle.load(file)

# with open(PATH + 'X_test_w2v_self_trained.pkl', mode='rb') as file:
    # X_test_w2v_self_trained = pickle.load(file)

with open(PATH + 'WordsIdPad_train.pkl', mode='rb') as file:
    WordsIdPad_train = pickle.load(file)

# with open(PATH + 'X_test_ft_pre_trained.pkl', mode='rb') as file:
    # X_test_ft_pre_trained = pickle.load(file)

# with open(PATH + 'X_train_ft_self_trained.pkl', mode='rb') as file:
    # X_train_ft_self_trained = pickle.load(file)

with open(PATH + 'WordsIdPad_test.pkl', mode='rb') as file:
    WordsIdPad_test = pickle.load(file)

# with open(PATH + 'X_test_ft_self_trained.pkl', mode='rb') as file:
    # X_test_ft_self_trained = pickle.load(file)

# with open(PATH + 'X_train_w2v_self_trained.pkl', mode='rb') as file:
    # X_train_w2v_self_trained = pickle.load(file)

with open(PATH + 'y_train.pkl', mode='rb') as file:
    y_train = pickle.load(file)

with open(PATH + 'y_test.pkl', mode='rb') as file:
    y_test = pickle.load(file)

# %%
param_grid = {
    # "embeddings": ['w2v_pretrained', 'ft_pretrained', 'w2v_selftrained', 'ft_selftrained', 'torch.nn'],
    "activation_fn": [F.relu],
    "learning_rate": [0.001],
    "epochs": [5, 10, 20, 50],
    "batch_size": [1024, 2048],
    "optimizer": [optim.AdamW],
    "layers_count": [i for i in range(1, 6)],
    "type_rnn": [torch.nn.RNN, torch.nn.LSTM, torch.nn.GRU],
    "hidden_size": [100, 300],
    "bidirectional": [False, True],
}

params_list = ParameterGrid(param_grid)
len(params_list)
# Out:
# 480

# %%
from sklearn.model_selection import train_test_split

class NetData(pl.LightningDataModule):
    def __init__(self, train_features=None, test_features=None, train_targets=None, test_targets=None, batch_size=None, random_state=None):
        super().__init__()
        
        self.batch_size = batch_size
        self.X_train, self.X_val, self.y_train, self.y_val = train_test_split(train_features, train_targets, random_state=random_state)
        self.X_test, self.y_test = test_features, test_targets

    def setup(self, stage=None):
        features_train = torch.tensor(self.X_train, dtype=torch.int32)
        targets_train = torch.tensor(self.y_train, device=device, dtype=torch.int32)
    
        features_val = torch.tensor(self.X_val, dtype=torch.int32)
        targets_val = torch.tensor(self.y_val, device=device, dtype=torch.int32)
    
        features_test = torch.tensor(self.X_test, dtype=torch.int32)
        targets_test = torch.tensor(self.y_test, dtype=torch.int32)
    
        self.trainset = data_utils.TensorDataset(features_train, targets_train)
        self.valset = data_utils.TensorDataset(features_val, targets_val)
        self.testset = data_utils.TensorDataset(features_test, targets_test)
        
    def train_dataloader(self):
        return data_utils.DataLoader(self.trainset, batch_size=self.batch_size)
    def val_dataloader(self):
        return data_utils.DataLoader(self.valset, batch_size=self.batch_size)
    def test_dataloader(self):
        return data_utils.DataLoader(self.testset, batch_size=self.batch_size)

# %%
from torchmetrics.classification import F1Score

class Net(pl.LightningModule):
    def __init__(self,
                 layers_count=None, 
                 activation_function=None,
                 type_rnn=None,
                 hidden_size=None,
                 bidirectional=None,
                 optimizer=None,
                 learningRate=None
                ):
        
        super().__init__()

        
        self.embedding_size = 300
        self.num_words = 10000
        self.seq_len = 20
        self.optim = optimizer
        self.learningRate = learningRate

        self.f1 = F1Score(task='multiclass', num_classes=2, multidim_average='global', average='weighted')
        
        self.embedding = nn.Embedding(self.num_words + 1, self.embedding_size, padding_idx=0)
        
        self.fa = activation_function
        
        self.rnn = type_rnn(
                input_size = self.embedding_size,
                hidden_size = hidden_size,
                num_layers = layers_count,
                bidirectional = bidirectional,
                batch_first = True
        )
        
        self.fc = nn.Linear(hidden_size * self.seq_len * (1+bidirectional), 2)
        
        

    def forward(self, x):
        x = self.embedding(x)
        x = x.reshape(len(x), self.seq_len, self.embedding_size)
        
        x, size = self.rnn(x)
        
        x = self.fc(x.reshape(x.shape[0], -1))
        
        return F.log_softmax(x, dim=-1)
    
    def configure_optimizers(self):
        optimizer = self.optim(self.parameters(), lr=self.learningRate)
        return optimizer
    
    def training_step(self, batch, batch_idx):
        x, y = batch
        y_hat = self(x)
        loss = F.cross_entropy(y_hat, y.long())
        return loss
    
    def validation_step(self, batch, batch_idx):
        x, y = batch
        pred = self(x)
        self.log("val_f1", self.f1(pred, y), on_epoch=True)

    def test_step(self, batch, batch_idx):
        x, y = batch
        pred = self(x)
        self.log("test_f1", self.f1(pred, y), on_epoch=True)

# %%
from IPython.display import clear_output
from tqdm import tqdm
total = []

for params in tqdm(params_list):
    
    clear_output(wait=True)  

    learningRate = params['learning_rate']
    optimizer_type = params['optimizer']
    layers_count = params['layers_count']
    batch_size = params['batch_size']
    epochs = params['epochs']
    fa = params['activation_fn']
    type_rnn = params['type_rnn']
    hidden_size = params['hidden_size']
    bidirectional = params['bidirectional']


    net = Net(
        layers_count=layers_count,
        activation_function=fa,
        type_rnn=type_rnn,
        hidden_size=hidden_size,
        bidirectional=bidirectional,
        optimizer=optimizer_type,
        learningRate=learningRate
        )
    dm = NetData(
        train_features=WordsIdPad_train,
        test_features=WordsIdPad_test,
        train_targets=y_train,
        test_targets=y_test,
        batch_size=batch_size,
        random_state=random_state
    )
    trainer = L.Trainer(logger=False, max_epochs=epochs, enable_progress_bar=True, deterministic=True, inference_mode=True, enable_checkpointing=False)
    trainer.fit(net, datamodule=dm)
    f1_val = trainer.validate(net, datamodule=dm)[-1]['val_f1']
    f1_test = trainer.test(net, datamodule=dm)[-1]['test_f1']
    
    total.append({
        'Type RNN': type_rnn.__name__,
        'hidden_size': hidden_size,
        'optimizer': optimizer_type.__name__,
        'batch_size': batch_size,
        'bidirectional': bidirectional,
        'Количество слоев': layers_count,
        'Количество эпох': epochs,
        'F1-val': round(f1_val, 4),
        'F1-test': round(f1_test, 4)
    })
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name      | Type              | Params
# ------------------------------------------------
# 0 | f1        | MulticlassF1Score | 0
# 1 | embedding | Embedding         | 3.0 M
# 2 | rnn       | GRU               | 7.6 M
# 3 | fc        | Linear            | 24.0 K
# ------------------------------------------------
# 10.6 M    Trainable params
# 0         Non-trainable params
# 10.6 M    Total params
# 42.409    Total estimated model params size (MB)
# Epoch 49: 100%|██████████| 9/9 [00:04<00:00,  1.86it/s]
# `Trainer.fit` stopped: `max_epochs=50` reached.
# Epoch 49: 100%|██████████| 9/9 [00:04<00:00,  1.86it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00,  6.97it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃  Runningstage.validating  ┃                           ┃
# ┃          metric           ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │          val_f1           │    0.7155896425247192     │
# └───────────────────────────┴───────────────────────────┘
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 84.36it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃   Runningstage.testing    ┃                           ┃
# ┃          metric           ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │          test_f1          │    0.7204486727714539     │
# └───────────────────────────┴───────────────────────────┘
# 100%|██████████| 480/480 [5:23:02<00:00, 40.38s/it]

# %%
print(datetime.datetime.now().strftime('%d-%B-%Y %H:%M:%S'))
# Out:
# 26-May-2023 18:38:17

# %% [markdown]
# # Сводная таблица

# %%
pd.set_option('display.max_rows', None)
summary = pd.DataFrame.from_dict(total)
summary_sort = summary.sort_values(by='F1-val', ascending=False)
summary_sort
# Out:
#     Type RNN  hidden_size optimizer  batch_size  bidirectional  \
# 130     LSTM          100     AdamW        1024           True
# 1       LSTM          100     AdamW        1024          False
# 400     LSTM          100     AdamW        2048           True
# 10      LSTM          100     AdamW        1024          False
# 133     LSTM          100     AdamW        1024           True
# 4       LSTM          100     AdamW        1024          False
# 478     LSTM          300     AdamW        2048           True
# 127     LSTM          100     AdamW        1024           True
# 148     LSTM          300     AdamW        1024           True
# 262     LSTM          300     AdamW        2048          False
# 238     LSTM          300     AdamW        1024           True
# 5        GRU          100     AdamW        1024          False
# 142     LSTM          300     AdamW        1024           True
# 457     LSTM          100     AdamW        2048           True
# 29       GRU          300     AdamW        1024          False
# 122      GRU          100     AdamW        1024           True
# 86       GRU          300     AdamW        1024          False
# 394     LSTM          100     AdamW        2048           True
# 418     LSTM          300     AdamW        2048           True
# 361     LSTM          100     AdamW        2048           True
# 220     LSTM          100     AdamW        1024           True
# 58      LSTM          300     AdamW        1024          False
# 259     LSTM          300     AdamW        2048          False
# 241     LSTM          100     AdamW        2048          False
# 427     LSTM          100     AdamW        2048           True
# 454     LSTM          100     AdamW        2048           True
# 370     LSTM          100     AdamW        2048           True
# 82      LSTM          300     AdamW        1024          False
# 464      GRU          100     AdamW        2048           True
# 460     LSTM          100     AdamW        2048           True
# 233      GRU          300     AdamW        1024           True
# 232     LSTM          300     AdamW        1024           True
# 55      LSTM          300     AdamW        1024          False
# 424     LSTM          100     AdamW        2048           True
# 14       GRU          100     AdamW        1024          False
# 217     LSTM          100     AdamW        1024           True
# 7       LSTM          100     AdamW        1024          False
# 205     LSTM          300     AdamW        1024           True
# 244     LSTM          100     AdamW        2048          False
# 475     LSTM          300     AdamW        2048           True
# 319     LSTM          300     AdamW        2048          False
# 316     LSTM          300     AdamW        2048          False
# 121     LSTM          100     AdamW        1024           True
# 452      GRU          100     AdamW        2048           True
# 182      GRU          100     AdamW        1024           True
# 364     LSTM          100     AdamW        2048           True
# 11       GRU          100     AdamW        1024          False
# 124     LSTM          100     AdamW        1024           True
# 466     LSTM          300     AdamW        2048           True
# 88      LSTM          300     AdamW        1024          False
# 298     LSTM          300     AdamW        2048          False
# 2        GRU          100     AdamW        1024          False
# 334     LSTM          100     AdamW        2048          False
# 208     LSTM          300     AdamW        1024           True
# 166     LSTM          300     AdamW        1024           True
# 397     LSTM          100     AdamW        2048           True
# 245      GRU          100     AdamW        2048          False
# 113      GRU          300     AdamW        1024          False
# 436     LSTM          300     AdamW        2048           True
# 181     LSTM          100     AdamW        1024           True
# 332      GRU          100     AdamW        2048          False
# 254      GRU          100     AdamW        2048          False
# 362      GRU          100     AdamW        2048           True
# 91      LSTM          100     AdamW        1024          False
# 347      GRU          300     AdamW        2048          False
# 61      LSTM          100     AdamW        1024          False
# 367     LSTM          100     AdamW        2048           True
# 193     LSTM          100     AdamW        1024           True
# 85      LSTM          300     AdamW        1024          False
# 97      LSTM          100     AdamW        1024          False
# 145     LSTM          300     AdamW        1024           True
# 257      GRU          300     AdamW        2048          False
# 389      GRU          300     AdamW        2048           True
# 116      GRU          300     AdamW        1024          False
# 185      GRU          100     AdamW        1024           True
# 94      LSTM          100     AdamW        1024          False
# 239      GRU          300     AdamW        1024           True
# 26       GRU          300     AdamW        1024          False
# 178     LSTM          300     AdamW        1024           True
# 109     LSTM          300     AdamW        1024          False
# 92       GRU          100     AdamW        1024          False
# 352     LSTM          300     AdamW        2048          False
# 31      LSTM          100     AdamW        1024          False
# 8        GRU          100     AdamW        1024          False
# 68       GRU          100     AdamW        1024          False
# 472     LSTM          300     AdamW        2048           True
# 212      GRU          100     AdamW        1024           True
# 371      GRU          100     AdamW        2048           True
# 115     LSTM          300     AdamW        1024          False
# 106     LSTM          300     AdamW        1024          False
# 107      GRU          300     AdamW        1024          False
# 331     LSTM          100     AdamW        2048          False
# 214     LSTM          100     AdamW        1024           True
# 421     LSTM          100     AdamW        2048           True
# 373     LSTM          100     AdamW        2048           True
# 190     LSTM          100     AdamW        1024           True
# 395      GRU          100     AdamW        2048           True
# 56       GRU          300     AdamW        1024          False
# 184     LSTM          100     AdamW        1024           True
# 382     LSTM          300     AdamW        2048           True
# 365      GRU          100     AdamW        2048           True
# 215      GRU          100     AdamW        1024           True
# 44       GRU          100     AdamW        1024          False
# 368      GRU          100     AdamW        2048           True
# 335      GRU          100     AdamW        2048          False
# 89       GRU          300     AdamW        1024          False
# 83       GRU          300     AdamW        1024          False
# 203      GRU          300     AdamW        1024           True
# 251      GRU          100     AdamW        2048          False
# 218      GRU          100     AdamW        1024           True
# 194      GRU          100     AdamW        1024           True
# 229     LSTM          300     AdamW        1024           True
# 103     LSTM          100     AdamW        1024          False
# 209      GRU          300     AdamW        1024           True
# 191      GRU          100     AdamW        1024           True
# 479      GRU          300     AdamW        2048           True
# 23       GRU          300     AdamW        1024          False
# 422      GRU          100     AdamW        2048           True
# 374      GRU          100     AdamW        2048           True
# 125      GRU          100     AdamW        1024           True
# 451     LSTM          100     AdamW        2048           True
# 19      LSTM          300     AdamW        1024          False
# 343     LSTM          100     AdamW        2048          False
# 322     LSTM          300     AdamW        2048          False
# 463     LSTM          100     AdamW        2048           True
# 49      LSTM          300     AdamW        1024          False
# 337     LSTM          100     AdamW        2048          False
# 265     LSTM          300     AdamW        2048          False
# 263      GRU          300     AdamW        2048          False
# 398      GRU          100     AdamW        2048           True
# 64      LSTM          100     AdamW        1024          False
# 25      LSTM          300     AdamW        1024          False
# 350      GRU          300     AdamW        2048          False
# 76      LSTM          300     AdamW        1024          False
# 338      GRU          100     AdamW        2048          False
# 202     LSTM          300     AdamW        1024           True
# 52      LSTM          300     AdamW        1024          False
# 284      GRU          100     AdamW        2048          False
# 80       GRU          300     AdamW        1024          False
# 101      GRU          100     AdamW        1024          False
# 248      GRU          100     AdamW        2048          False
# 211     LSTM          100     AdamW        1024           True
# 196     LSTM          300     AdamW        1024           True
# 302      GRU          100     AdamW        2048          False
# 118     LSTM          300     AdamW        1024          False
# 250     LSTM          100     AdamW        2048          False
# 235     LSTM          300     AdamW        1024           True
# 379     LSTM          300     AdamW        2048           True
# 260      GRU          300     AdamW        2048          False
# 281      GRU          100     AdamW        2048          False
# 187     LSTM          100     AdamW        1024           True
# 439     LSTM          300     AdamW        2048           True
# 13      LSTM          100     AdamW        1024          False
# 445     LSTM          300     AdamW        2048           True
# 353      GRU          300     AdamW        2048          False
# 199     LSTM          300     AdamW        1024           True
# 476      GRU          300     AdamW        2048           True
# 32       GRU          100     AdamW        1024          False
# 247     LSTM          100     AdamW        2048          False
# 53       GRU          300     AdamW        1024          False
# 62       GRU          100     AdamW        1024          False
# 256     LSTM          300     AdamW        2048          False
# 455      GRU          100     AdamW        2048           True
# 253     LSTM          100     AdamW        2048          False
# 461      GRU          100     AdamW        2048           True
# 272      GRU          100     AdamW        2048          False
# 355     LSTM          300     AdamW        2048          False
# 206      GRU          300     AdamW        1024           True
# 188      GRU          100     AdamW        1024           True
# 17       GRU          300     AdamW        1024          False
# 70      LSTM          100     AdamW        1024          False
# 221      GRU          100     AdamW        1024           True
# 467      GRU          300     AdamW        2048           True
# 163     LSTM          100     AdamW        1024           True
# 392      GRU          100     AdamW        2048           True
# 358     LSTM          300     AdamW        2048          False
# 242      GRU          100     AdamW        2048          False
# 154     LSTM          100     AdamW        1024           True
# 289     LSTM          300     AdamW        2048          False
# 469     LSTM          300     AdamW        2048           True
# 226     LSTM          300     AdamW        1024           True
# 119      GRU          300     AdamW        1024          False
# 442     LSTM          300     AdamW        2048           True
# 200      GRU          300     AdamW        1024           True
# 356      GRU          300     AdamW        2048          False
# 376     LSTM          300     AdamW        2048           True
# 74       GRU          100     AdamW        1024          False
# 175     LSTM          300     AdamW        1024           True
# 155      GRU          100     AdamW        1024           True
# 169     LSTM          300     AdamW        1024           True
# 71       GRU          100     AdamW        1024          False
# 301     LSTM          100     AdamW        2048          False
# 22      LSTM          300     AdamW        1024          False
# 227      GRU          300     AdamW        1024           True
# 346     LSTM          300     AdamW        2048          False
# 149      GRU          300     AdamW        1024           True
# 79      LSTM          300     AdamW        1024          False
# 98       GRU          100     AdamW        1024          False
# 151     LSTM          100     AdamW        1024           True
# 329      GRU          300     AdamW        2048          False
# 136     LSTM          300     AdamW        1024           True
# 77       GRU          300     AdamW        1024          False
# 236      GRU          300     AdamW        1024           True
# 325     LSTM          300     AdamW        2048          False
# 266      GRU          300     AdamW        2048          False
# 275      GRU          100     AdamW        2048          False
# 104      GRU          100     AdamW        1024          False
# 134      GRU          100     AdamW        1024           True
# 409     LSTM          300     AdamW        2048           True
# 341      GRU          100     AdamW        2048          False
# 158      GRU          100     AdamW        1024           True
# 110      GRU          300     AdamW        1024          False
# 349     LSTM          300     AdamW        2048          False
# 176      GRU          300     AdamW        1024           True
# 41       GRU          100     AdamW        1024          False
# 269      GRU          300     AdamW        2048          False
# 73      LSTM          100     AdamW        1024          False
# 146      GRU          300     AdamW        1024           True
# 268     LSTM          300     AdamW        2048          False
# 16      LSTM          300     AdamW        1024          False
# 458      GRU          100     AdamW        2048           True
# 224      GRU          100     AdamW        1024           True
# 37      LSTM          100     AdamW        1024          False
# 328     LSTM          300     AdamW        2048          False
# 35       GRU          100     AdamW        1024          False
# 340     LSTM          100     AdamW        2048          False
# 273      RNN          100     AdamW        2048          False
# 473      GRU          300     AdamW        2048           True
# 197      GRU          300     AdamW        1024           True
# 406     LSTM          300     AdamW        2048           True
# 344      GRU          100     AdamW        2048          False
# 410      GRU          300     AdamW        2048           True
# 386      GRU          300     AdamW        2048           True
# 286     LSTM          300     AdamW        2048          False
# 314      GRU          100     AdamW        2048          False
# 38       GRU          100     AdamW        1024          False
# 157     LSTM          100     AdamW        1024           True
# 131      GRU          100     AdamW        1024           True
# 95       GRU          100     AdamW        1024          False
# 359      GRU          300     AdamW        2048          False
# 40      LSTM          100     AdamW        1024          False
# 448     LSTM          300     AdamW        2048           True
# 65       GRU          100     AdamW        1024          False
# 437      GRU          300     AdamW        2048           True
# 112     LSTM          300     AdamW        1024          False
# 431      GRU          100     AdamW        2048           True
# 304     LSTM          100     AdamW        2048          False
# 230      GRU          300     AdamW        1024           True
# 271     LSTM          100     AdamW        2048          False
# 173      GRU          300     AdamW        1024           True
# 67      LSTM          100     AdamW        1024          False
# 167      GRU          300     AdamW        1024           True
# 401      GRU          100     AdamW        2048           True
# 390      RNN          100     AdamW        2048           True
# 377      GRU          300     AdamW        2048           True
# 179      GRU          300     AdamW        1024           True
# 470      GRU          300     AdamW        2048           True
# 3        RNN          100     AdamW        1024          False
# 413      GRU          300     AdamW        2048           True
# 292     LSTM          300     AdamW        2048          False
# 380      GRU          300     AdamW        2048           True
# 326      GRU          300     AdamW        2048          False
# 72       RNN          100     AdamW        1024          False
# 293      GRU          300     AdamW        2048          False
# 152      GRU          100     AdamW        1024           True
# 419      GRU          300     AdamW        2048           True
# 46      LSTM          300     AdamW        1024          False
# 172     LSTM          300     AdamW        1024           True
# 305      GRU          100     AdamW        2048          False
# 383      GRU          300     AdamW        2048           True
# 404      GRU          100     AdamW        2048           True
# 87       RNN          300     AdamW        1024          False
# 20       GRU          300     AdamW        1024          False
# 385     LSTM          300     AdamW        2048           True
# 295     LSTM          300     AdamW        2048          False
# 412     LSTM          300     AdamW        2048           True
# 290      GRU          300     AdamW        2048          False
# 170      GRU          300     AdamW        1024           True
# 440      GRU          300     AdamW        2048           True
# 287      GRU          300     AdamW        2048          False
# 299      GRU          300     AdamW        2048          False
# 137      GRU          300     AdamW        1024           True
# 300      RNN          100     AdamW        2048          False
# 450      RNN          100     AdamW        2048           True
# 415     LSTM          300     AdamW        2048           True
# 43      LSTM          100     AdamW        1024          False
# 425      GRU          100     AdamW        2048           True
# 33       RNN          100     AdamW        1024          False
# 12       RNN          100     AdamW        1024          False
# 164      GRU          100     AdamW        1024           True
# 139     LSTM          300     AdamW        1024           True
# 296      GRU          300     AdamW        2048          False
# 330      RNN          100     AdamW        2048          False
# 47       GRU          300     AdamW        1024          False
# 42       RNN          100     AdamW        1024          False
# 276      RNN          100     AdamW        2048          False
# 143      GRU          300     AdamW        1024           True
# 308      GRU          100     AdamW        2048          False
# 90       RNN          100     AdamW        1024          False
# 309      RNN          100     AdamW        2048          False
# 317      GRU          300     AdamW        2048          False
# 59       GRU          300     AdamW        1024          False
# 449      GRU          300     AdamW        2048           True
# 407      GRU          300     AdamW        2048           True
# 150      RNN          100     AdamW        1024           True
# 140      GRU          300     AdamW        1024           True
# 270      RNN          100     AdamW        2048          False
# 117      RNN          300     AdamW        1024          False
# 60       RNN          100     AdamW        1024          False
# 9        RNN          100     AdamW        1024          False
# 30       RNN          100     AdamW        1024          False
# 6        RNN          100     AdamW        1024          False
# 234      RNN          300     AdamW        1024           True
# 128      GRU          100     AdamW        1024           True
# 120      RNN          100     AdamW        1024           True
# 207      RNN          300     AdamW        1024           True
# 210      RNN          100     AdamW        1024           True
# 0        RNN          100     AdamW        1024          False
# 388     LSTM          300     AdamW        2048           True
# 99       RNN          100     AdamW        1024          False
# 50       GRU          300     AdamW        1024          False
# 102      RNN          100     AdamW        1024          False
# 39       RNN          100     AdamW        1024          False
# 161      GRU          100     AdamW        1024           True
# 243      RNN          100     AdamW        2048          False
# 274     LSTM          100     AdamW        2048          False
# 280     LSTM          100     AdamW        2048          False
# 279      RNN          100     AdamW        2048          False
# 339      RNN          100     AdamW        2048          False
# 66       RNN          100     AdamW        1024          False
# 363      RNN          100     AdamW        2048           True
# 433     LSTM          100     AdamW        2048           True
# 366      RNN          100     AdamW        2048           True
# 93       RNN          100     AdamW        1024          False
# 28      LSTM          300     AdamW        1024          False
# 416      GRU          300     AdamW        2048           True
# 36       RNN          100     AdamW        1024          False
# 360      RNN          100     AdamW        2048           True
# 96       RNN          100     AdamW        1024          False
# 114      RNN          300     AdamW        1024          False
# 303      RNN          100     AdamW        2048          False
# 180      RNN          100     AdamW        1024           True
# 69       RNN          100     AdamW        1024          False
# 342      RNN          100     AdamW        2048          False
# 237      RNN          300     AdamW        1024           True
# 75       RNN          300     AdamW        1024          False
# 123      RNN          100     AdamW        1024           True
# 126      RNN          100     AdamW        1024           True
# 246      RNN          100     AdamW        2048          False
# 84       RNN          300     AdamW        1024          False
# 443      GRU          300     AdamW        2048           True
# 189      RNN          100     AdamW        1024           True
# 219      RNN          100     AdamW        1024           True
# 333      RNN          100     AdamW        2048          False
# 204      RNN          300     AdamW        1024           True
# 18       RNN          300     AdamW        1024          False
# 108      RNN          300     AdamW        1024          False
# 186      RNN          100     AdamW        1024           True
# 57       RNN          300     AdamW        1024          False
# 34      LSTM          100     AdamW        1024          False
# 240      RNN          100     AdamW        2048          False
# 183      RNN          100     AdamW        1024           True
# 336      RNN          100     AdamW        2048          False
# 153      RNN          100     AdamW        1024           True
# 249      RNN          100     AdamW        2048          False
# 446      GRU          300     AdamW        2048           True
# 111      RNN          300     AdamW        1024          False
# 453      RNN          100     AdamW        2048           True
# 129      RNN          100     AdamW        1024           True
# 430     LSTM          100     AdamW        2048           True
# 403     LSTM          100     AdamW        2048           True
# 462      RNN          100     AdamW        2048           True
# 222      RNN          100     AdamW        1024           True
# 399      RNN          100     AdamW        2048           True
# 258      RNN          300     AdamW        2048          False
# 261      RNN          300     AdamW        2048          False
# 369      RNN          100     AdamW        2048           True
# 312      RNN          100     AdamW        2048          False
# 198      RNN          300     AdamW        1024           True
# 438      RNN          300     AdamW        2048           True
# 267      RNN          300     AdamW        2048          False
# 177      RNN          300     AdamW        1024           True
# 225      RNN          300     AdamW        1024           True
# 100     LSTM          100     AdamW        1024          False
# 228      RNN          300     AdamW        1024           True
# 405      RNN          300     AdamW        2048           True
# 477      RNN          300     AdamW        2048           True
# 231      RNN          300     AdamW        1024           True
# 321      RNN          300     AdamW        2048          False
# 357      RNN          300     AdamW        2048          False
# 420      RNN          100     AdamW        2048           True
# 216      RNN          100     AdamW        1024           True
# 434      GRU          100     AdamW        2048           True
# 423      RNN          100     AdamW        2048           True
# 426      RNN          100     AdamW        2048           True
# 255      RNN          300     AdamW        2048          False
# 393      RNN          100     AdamW        2048           True
# 105      RNN          300     AdamW        1024          False
# 54       RNN          300     AdamW        1024          False
# 160     LSTM          100     AdamW        1024           True
# 192      RNN          100     AdamW        1024           True
# 78       RNN          300     AdamW        1024          False
# 315      RNN          300     AdamW        2048          False
# 323      GRU          300     AdamW        2048          False
# 283     LSTM          100     AdamW        2048          False
# 63       RNN          100     AdamW        1024          False
# 444      RNN          300     AdamW        2048           True
# 345      RNN          300     AdamW        2048          False
# 375      RNN          300     AdamW        2048           True
# 48       RNN          300     AdamW        1024          False
# 372      RNN          100     AdamW        2048           True
# 282      RNN          100     AdamW        2048          False
# 465      RNN          300     AdamW        2048           True
# 348      RNN          300     AdamW        2048          False
# 432      RNN          100     AdamW        2048           True
# 195      RNN          300     AdamW        1024           True
# 468      RNN          300     AdamW        2048           True
# 387      RNN          300     AdamW        2048           True
# 429      RNN          100     AdamW        2048           True
# 456      RNN          100     AdamW        2048           True
# 223     LSTM          100     AdamW        1024           True
# 213      RNN          100     AdamW        1024           True
# 354      RNN          300     AdamW        2048          False
# 201      RNN          300     AdamW        1024           True
# 471      RNN          300     AdamW        2048           True
# 320      GRU          300     AdamW        2048          False
# 45       RNN          300     AdamW        1024          False
# 252      RNN          100     AdamW        2048          False
# 132      RNN          100     AdamW        1024           True
# 447      RNN          300     AdamW        2048           True
# 313     LSTM          100     AdamW        2048          False
# 24       RNN          300     AdamW        1024          False
# 428      GRU          100     AdamW        2048           True
# 156      RNN          100     AdamW        1024           True
# 288      RNN          300     AdamW        2048          False
# 474      RNN          300     AdamW        2048           True
# 165      RNN          300     AdamW        1024           True
# 81       RNN          300     AdamW        1024          False
# 168      RNN          300     AdamW        1024           True
# 408      RNN          300     AdamW        2048           True
# 311      GRU          100     AdamW        2048          False
# 278      GRU          100     AdamW        2048          False
# 441      RNN          300     AdamW        2048           True
# 351      RNN          300     AdamW        2048          False
# 162      RNN          100     AdamW        1024           True
# 306      RNN          100     AdamW        2048          False
# 21       RNN          300     AdamW        1024          False
# 174      RNN          300     AdamW        1024           True
# 435      RNN          300     AdamW        2048           True
# 310     LSTM          100     AdamW        2048          False
# 264      RNN          300     AdamW        2048          False
# 277     LSTM          100     AdamW        2048          False
# 459      RNN          100     AdamW        2048           True
# 414      RNN          300     AdamW        2048           True
# 51       RNN          300     AdamW        1024          False
# 307     LSTM          100     AdamW        2048          False
# 171      RNN          300     AdamW        1024           True
# 141      RNN          300     AdamW        1024           True
# 318      RNN          300     AdamW        2048          False
# 402      RNN          100     AdamW        2048           True
# 378      RNN          300     AdamW        2048           True
# 297      RNN          300     AdamW        2048          False
# 294      RNN          300     AdamW        2048          False
# 27       RNN          300     AdamW        1024          False
# 324      RNN          300     AdamW        2048          False
# 417      RNN          300     AdamW        2048           True
# 15       RNN          300     AdamW        1024          False
# 159      RNN          100     AdamW        1024           True
# 391     LSTM          100     AdamW        2048           True
# 327      RNN          300     AdamW        2048          False
# 138      RNN          300     AdamW        1024           True
# 135      RNN          300     AdamW        1024           True
# 381      RNN          300     AdamW        2048           True
# 291      RNN          300     AdamW        2048          False
# 384      RNN          300     AdamW        2048           True
# 285      RNN          300     AdamW        2048          False
# 144      RNN          300     AdamW        1024           True
# 147      RNN          300     AdamW        1024           True
# 396      RNN          100     AdamW        2048           True
# 411      RNN          300     AdamW        2048           True
#
#      Количество слоев  Количество эпох  F1-val  F1-test
# 130                 4                5  0.7312   0.7130
# 1                   1                5  0.7312   0.7729
# 400                 4               10  0.7303   0.6785
# 10                  4                5  0.7298   0.7759
# 133                 5                5  0.7296   0.7186
# 4                   2                5  0.7294   0.7186
# 478                 5               50  0.7286   0.7759
# 127                 3                5  0.7282   0.7316
# 148                 5                5  0.7279   0.7600
# 262                 3                5  0.7278   0.7204
# 238                 5               50  0.7276   0.7588
# 5                   2                5  0.7275   0.6974
# 142                 3                5  0.7273   0.6571
# 457                 3               50  0.7272   0.6571
# 29                  5                5  0.7269   0.6944
# 122                 1                5  0.7269   0.6400
# 86                  4               20  0.7267   0.7378
# 394                 2               10  0.7260   0.7130
# 418                 5               10  0.7257   0.7187
# 361                 1                5  0.7256   0.7200
# 220                 4               50  0.7251   0.6593
# 58                  5               10  0.7249   0.8185
# 259                 2                5  0.7243   0.7200
# 241                 1                5  0.7240   0.8196
# 427                 3               20  0.7240   0.7600
# 454                 2               50  0.7239   0.7796
# 370                 4                5  0.7237   0.7600
# 82                  3               20  0.7236   0.7759
# 464                 5               50  0.7234   0.7588
# 460                 4               50  0.7234   0.7204
# 233                 3               50  0.7232   0.6994
# 232                 3               50  0.7231   0.7403
# 55                  4               10  0.7227   0.6994
# 424                 2               20  0.7227   0.6805
# 14                  5                5  0.7227   0.7540
# 217                 3               50  0.7227   0.7163
# 7                   3                5  0.7226   0.7378
# 205                 4               20  0.7226   0.7204
# 244                 2                5  0.7222   0.7588
# 475                 4               50  0.7221   0.8003
# 319                 2               20  0.7221   0.6784
# 316                 1               20  0.7219   0.7588
# 121                 1                5  0.7218   0.7200
# 452                 1               50  0.7215   0.7568
# 182                 1               20  0.7214   0.6758
# 364                 2                5  0.7214   0.6994
# 11                  4                5  0.7211   0.7600
# 124                 2                5  0.7210   0.6903
# 466                 1               50  0.7210   0.7803
# 88                  5               20  0.7209   0.6593
# 298                 5               10  0.7209   0.7588
# 2                   1                5  0.7209   0.7990
# 334                 2               50  0.7207   0.6382
# 208                 5               20  0.7207   0.7803
# 166                 1               10  0.7204   0.7604
# 397                 3               10  0.7203   0.7204
# 245                 2                5  0.7203   0.6800
# 113                 3               50  0.7198   0.7352
# 436                 1               20  0.7197   0.8000
# 181                 1               20  0.7196   0.7186
# 332                 1               50  0.7196   0.7796
# 254                 5                5  0.7195   0.7803
# 362                 1                5  0.7193   0.6400
# 91                  1               50  0.7192   0.7796
# 347                 1               50  0.7192   0.7204
# 61                  1               20  0.7191   0.7990
# 367                 3                5  0.7191   0.7030
# 193                 5               20  0.7190   0.7395
# 85                  4               20  0.7189   0.7378
# 97                  3               50  0.7188   0.7588
# 145                 4                5  0.7187   0.6974
# 257                 1                5  0.7186   0.7781
# 389                 5                5  0.7185   0.8185
# 116                 4               50  0.7183   0.7395
# 185                 2               20  0.7181   0.7200
# 94                  2               50  0.7181   0.7186
# 239                 5               50  0.7179   0.7974
# 26                  4                5  0.7178   0.7540
# 178                 5               10  0.7178   0.6994
# 109                 2               50  0.7178   0.7600
# 92                  1               50  0.7177   0.7378
# 352                 3               50  0.7177   0.7395
# 31                  1               10  0.7177   0.7604
# 8                   3                5  0.7176   0.6353
# 68                  3               20  0.7176   0.6944
# 472                 3               50  0.7176   0.7004
# 212                 1               50  0.7175   0.8000
# 371                 4                5  0.7175   0.7781
# 115                 4               50  0.7173   0.6784
# 106                 1               50  0.7173   0.8196
# 107                 1               50  0.7173   0.7600
# 331                 1               50  0.7172   0.7974
# 214                 2               50  0.7170   0.6604
# 421                 1               20  0.7170   0.7588
# 373                 5                5  0.7169   0.7803
# 190                 4               20  0.7169   0.6974
# 395                 2               10  0.7169   0.7186
# 56                  4               10  0.7168   0.8400
# 184                 2               20  0.7166   0.6800
# 382                 3                5  0.7166   0.7164
# 365                 2                5  0.7165   0.7600
# 215                 2               50  0.7164   0.7781
# 44                  5               10  0.7163   0.7130
# 368                 3                5  0.7163   0.7600
# 335                 2               50  0.7162   0.7378
# 89                  5               20  0.7162   0.7378
# 83                  3               20  0.7161   0.8185
# 203                 3               20  0.7161   0.6994
# 251                 4                5  0.7160   0.6800
# 218                 3               50  0.7159   0.7600
# 194                 5               20  0.7158   0.7200
# 229                 2               50  0.7158   0.7395
# 103                 5               50  0.7157   0.7378
# 209                 5               20  0.7156   0.7204
# 191                 4               20  0.7156   0.7204
# 479                 5               50  0.7156   0.7204
# 23                  3                5  0.7156   0.7796
# 422                 1               20  0.7155   0.7186
# 374                 5                5  0.7154   0.6784
# 125                 2                5  0.7154   0.6974
# 451                 1               50  0.7153   0.7378
# 19                  2                5  0.7153   0.7186
# 343                 5               50  0.7153   0.7781
# 322                 3               20  0.7151   0.7600
# 463                 5               50  0.7150   0.6994
# 49                  2               10  0.7150   0.7588
# 337                 3               50  0.7149   0.7588
# 265                 4                5  0.7148   0.7588
# 263                 3                5  0.7146   0.6944
# 398                 3               10  0.7146   0.8000
# 64                  2               20  0.7145   0.6205
# 25                  4                5  0.7145   0.8167
# 350                 2               50  0.7144   0.8000
# 76                  1               20  0.7144   0.7729
# 338                 3               50  0.7144   0.7086
# 202                 3               20  0.7143   0.7200
# 52                  3               10  0.7143   0.7403
# 284                 5               10  0.7141   0.7004
# 80                  2               20  0.7140   0.6800
# 101                 4               50  0.7140   0.7163
# 248                 3                5  0.7139   0.8185
# 211                 1               50  0.7139   0.7540
# 196                 1               20  0.7139   0.8003
# 302                 1               20  0.7139   0.7796
# 118                 5               50  0.7138   0.7781
# 250                 4                5  0.7135   0.7796
# 235                 4               50  0.7135   0.6784
# 379                 2                5  0.7134   0.7187
# 260                 2                5  0.7134   0.6994
# 281                 4               10  0.7132   0.8000
# 187                 3               20  0.7131   0.7588
# 439                 2               20  0.7131   0.7403
# 13                  5                5  0.7131   0.6353
# 445                 4               20  0.7130   0.6903
# 353                 3               50  0.7128   0.6800
# 199                 2               20  0.7127   0.7796
# 476                 4               50  0.7126   0.6604
# 32                  1               10  0.7125   0.7130
# 247                 3                5  0.7125   0.7403
# 53                  3               10  0.7125   0.7600
# 62                  1               20  0.7125   0.7378
# 256                 1                5  0.7124   0.7796
# 455                 2               50  0.7123   0.7200
# 253                 5                5  0.7123   0.6490
# 461                 4               50  0.7122   0.7588
# 272                 1               10  0.7117   0.6974
# 355                 4               50  0.7114   0.7796
# 206                 4               20  0.7114   0.6800
# 188                 3               20  0.7113   0.7403
# 17                  1                5  0.7113   0.7600
# 70                  4               20  0.7113   0.6974
# 221                 4               50  0.7113   0.7200
# 467                 1               50  0.7112   0.7403
# 163                 5               10  0.7112   0.6593
# 392                 1               10  0.7111   0.6800
# 358                 5               50  0.7111   0.7604
# 242                 1                5  0.7111   0.7803
# 154                 2               10  0.7111   0.7352
# 289                 2               10  0.7111   0.7200
# 469                 2               50  0.7110   0.6400
# 226                 1               50  0.7109   0.8379
# 119                 5               50  0.7108   0.7781
# 442                 3               20  0.7108   0.8202
# 200                 2               20  0.7107   0.7395
# 356                 4               50  0.7105   0.7352
# 376                 1                5  0.7104   0.7974
# 74                  5               20  0.7103   0.6205
# 175                 4               10  0.7100   0.7540
# 155                 2               10  0.7098   0.7604
# 169                 2               10  0.7098   0.6994
# 71                  4               20  0.7096   0.6784
# 301                 1               20  0.7096   0.7796
# 22                  3                5  0.7096   0.7990
# 227                 1               50  0.7095   0.7200
# 346                 1               50  0.7094   0.7378
# 149                 5                5  0.7092   0.6604
# 79                  2               20  0.7091   0.8403
# 98                  3               50  0.7088   0.7163
# 151                 1               10  0.7088   0.7568
# 329                 5               20  0.7088   0.7395
# 136                 1                5  0.7087   0.7759
# 77                  1               20  0.7087   0.7796
# 236                 4               50  0.7085   0.7395
# 325                 4               20  0.7085   0.7950
# 266                 4                5  0.7081   0.7004
# 275                 2               10  0.7081   0.7403
# 104                 5               50  0.7079   0.6994
# 134                 5                5  0.7078   0.7796
# 409                 2               10  0.7078   0.7588
# 341                 4               50  0.7078   0.7352
# 158                 3               10  0.7076   0.6994
# 110                 2               50  0.7076   0.7200
# 349                 2               50  0.7075   0.7163
# 176                 4               10  0.7073   0.7352
# 41                  4               10  0.7073   0.7004
# 269                 5                5  0.7071   0.7187
# 73                  5               20  0.7070   0.6181
# 146                 4                5  0.7068   0.7186
# 268                 5                5  0.7067   0.7004
# 16                  1                5  0.7065   0.6720
# 458                 3               50  0.7064   0.7600
# 224                 5               50  0.7063   0.6593
# 37                  3               10  0.7062   0.6167
# 328                 5               20  0.7060   0.7403
# 35                  2               10  0.7059   0.7130
# 340                 4               50  0.7057   0.7200
# 273                 2               10  0.7053   0.7130
# 473                 3               50  0.7052   0.7600
# 197                 1               20  0.7051   0.7186
# 406                 1               10  0.7048   0.7403
# 344                 5               50  0.7047   0.7378
# 410                 2               10  0.7047   0.7803
# 386                 4                5  0.7043   0.7588
# 286                 1               10  0.7040   0.7403
# 314                 5               20  0.7039   0.7186
# 38                  3               10  0.7038   0.6800
# 157                 3               10  0.7036   0.6994
# 131                 4                5  0.7035   0.6720
# 95                  2               50  0.7033   0.7200
# 359                 5               50  0.7033   0.8000
# 40                  4               10  0.7029   0.7919
# 448                 5               20  0.7029   0.7974
# 65                  2               20  0.7027   0.7378
# 437                 1               20  0.7026   0.8000
# 112                 3               50  0.7025   0.6406
# 431                 4               20  0.7023   0.7588
# 304                 2               20  0.7017   0.6606
# 230                 2               50  0.7017   0.8000
# 271                 1               10  0.7014   0.6720
# 173                 3               10  0.7012   0.7604
# 67                  3               20  0.7011   0.8000
# 167                 1               10  0.7009   0.6800
# 401                 4               10  0.7009   0.7403
# 390                 1               10  0.7008   0.7204
# 377                 1                5  0.7008   0.7759
# 179                 5               10  0.7006   0.6571
# 470                 2               50  0.7005   0.6994
# 3                   2                5  0.7004   0.6974
# 413                 3               10  0.7003   0.7403
# 292                 3               10  0.7003   0.7316
# 380                 2                5  0.7000   0.7796
# 326                 4               20  0.6998   0.7378
# 72                  5               20  0.6997   0.7395
# 293                 3               10  0.6996   0.7164
# 152                 1               10  0.6995   0.7600
# 419                 5               10  0.6994   0.6784
# 46                  1               10  0.6991   0.6975
# 172                 3               10  0.6986   0.8000
# 305                 2               20  0.6986   0.7204
# 383                 3                5  0.6985   0.6785
# 404                 5               10  0.6982   0.7974
# 87                  5               20  0.6980   0.6593
# 20                  2                5  0.6979   0.7395
# 385                 4                5  0.6975   0.6205
# 295                 4               10  0.6974   0.7086
# 412                 3               10  0.6965   0.7919
# 290                 2               10  0.6960   0.7403
# 170                 2               10  0.6951   0.7395
# 440                 2               20  0.6950   0.7604
# 287                 1               10  0.6942   0.6800
# 299                 5               10  0.6938   0.6945
# 137                 1                5  0.6934   0.7378
# 300                 1               20  0.6932   0.7200
# 450                 1               50  0.6930   0.6604
# 415                 4               10  0.6929   0.7796
# 43                  5               10  0.6928   0.6784
# 425                 2               20  0.6919   0.7187
# 33                  2               10  0.6919   0.6571
# 12                  5                5  0.6917   0.8000
# 164                 5               10  0.6910   0.6205
# 139                 2                5  0.6909   0.6759
# 296                 4               10  0.6908   0.7403
# 330                 1               50  0.6900   0.7600
# 47                  1               10  0.6895   0.8000
# 42                  5               10  0.6894   0.6604
# 276                 3               10  0.6892   0.7187
# 143                 3                5  0.6891   0.6759
# 308                 3               20  0.6891   0.5924
# 90                  1               50  0.6889   0.6805
# 309                 4               20  0.6885   0.7187
# 317                 1               20  0.6880   0.7759
# 59                  5               10  0.6879   0.7395
# 449                 5               20  0.6873   0.7187
# 407                 1               10  0.6870   0.7803
# 150                 1               10  0.6865   0.7803
# 140                 2                5  0.6864   0.7803
# 270                 1               10  0.6864   0.6604
# 117                 5               50  0.6858   0.7781
# 60                  1               20  0.6857   0.7004
# 9                   4                5  0.6848   0.5391
# 30                  1               10  0.6847   0.7352
# 6                   3                5  0.6844   0.6382
# 234                 4               50  0.6843   0.8196
# 128                 3                5  0.6843   0.6903
# 120                 1                5  0.6842   0.7204
# 207                 5               20  0.6841   0.6974
# 210                 1               50  0.6839   0.7186
# 0                   1                5  0.6837   0.7604
# 388                 5                5  0.6835   0.6994
# 99                  4               50  0.6828   0.6800
# 50                  2               10  0.6821   0.7187
# 102                 5               50  0.6818   0.6593
# 39                  4               10  0.6813   0.6994
# 161                 4               10  0.6811   0.7030
# 243                 2                5  0.6809   0.7568
# 274                 2               10  0.6799   0.7353
# 280                 4               10  0.6799   0.6849
# 279                 4               10  0.6794   0.8202
# 339                 4               50  0.6793   0.6167
# 66                  3               20  0.6788   0.7186
# 363                 2                5  0.6785   0.7004
# 433                 5               20  0.6785   0.7030
# 366                 3                5  0.6784   0.7395
# 93                  2               50  0.6780   0.6571
# 28                  5                5  0.6776   0.6722
# 416                 4               10  0.6775   0.7187
# 36                  3               10  0.6774   0.6537
# 360                 1                5  0.6772   0.7378
# 96                  3               50  0.6771   0.6571
# 114                 4               50  0.6771   0.7990
# 303                 2               20  0.6770   0.7004
# 180                 1               20  0.6767   0.6805
# 69                  4               20  0.6765   0.6400
# 342                 5               50  0.6759   0.7200
# 237                 5               50  0.6749   0.7186
# 75                  1               20  0.6748   0.6400
# 123                 2                5  0.6746   0.7395
# 126                 3                5  0.6746   0.7004
# 246                 3                5  0.6746   0.8196
# 84                  4               20  0.6746   0.7004
# 443                 3               20  0.6746   0.7378
# 189                 4               20  0.6740   0.7200
# 219                 4               50  0.6739   0.6604
# 333                 2               50  0.6735   0.7004
# 204                 4               20  0.6731   0.7796
# 18                  2                5  0.6731   0.6571
# 108                 2               50  0.6730   0.7796
# 186                 3               20  0.6725   0.7403
# 57                  5               10  0.6725   0.6490
# 34                  2               10  0.6719   0.6538
# 240                 1                5  0.6718   0.7403
# 183                 2               20  0.6717   0.7352
# 336                 3               50  0.6711   0.6167
# 153                 2               10  0.6711   0.6994
# 249                 4                5  0.6709   0.7395
# 446                 4               20  0.6709   0.7378
# 111                 3               50  0.6706   0.8392
# 453                 2               50  0.6704   0.6604
# 129                 4                5  0.6698   0.7004
# 430                 4               20  0.6686   0.5842
# 403                 5               10  0.6686   0.6906
# 462                 5               50  0.6681   0.6784
# 222                 5               50  0.6678   0.7200
# 399                 4               10  0.6677   0.7403
# 258                 2                5  0.6674   0.6205
# 261                 3                5  0.6671   0.6805
# 369                 4                5  0.6669   0.7803
# 312                 5               20  0.6666   0.6784
# 198                 2               20  0.6665   0.6785
# 438                 2               20  0.6665   0.7403
# 267                 5                5  0.6661   0.7540
# 177                 5               10  0.6660   0.7352
# 225                 1               50  0.6658   0.7004
# 100                 4               50  0.6656   0.6538
# 228                 2               50  0.6656   0.6400
# 405                 1               10  0.6655   0.7186
# 477                 5               50  0.6653   0.7163
# 231                 3               50  0.6650   0.5981
# 321                 3               20  0.6647   0.6805
# 357                 5               50  0.6640   0.6604
# 420                 1               20  0.6638   0.7588
# 216                 3               50  0.6633   0.7395
# 434                 5               20  0.6631   0.6606
# 423                 2               20  0.6631   0.7004
# 426                 3               20  0.6628   0.8400
# 255                 1                5  0.6626   0.6805
# 393                 2               10  0.6622   0.6785
# 105                 1               50  0.6615   0.7186
# 54                  4               10  0.6615   0.7604
# 160                 4               10  0.6614   0.6855
# 192                 5               20  0.6614   0.6800
# 78                  2               20  0.6608   0.7204
# 315                 1               20  0.6607   0.6604
# 323                 3               20  0.6604   0.7316
# 283                 5               10  0.6603   0.5674
# 63                  2               20  0.6603   0.6974
# 444                 4               20  0.6598   0.7796
# 345                 1               50  0.6597   0.6800
# 375                 1                5  0.6597   0.6944
# 48                  2               10  0.6595   0.6406
# 372                 5                5  0.6586   0.6800
# 282                 5               10  0.6584   0.7600
# 465                 1               50  0.6584   0.6593
# 348                 2               50  0.6577   0.6994
# 432                 5               20  0.6576   0.7588
# 195                 1               20  0.6575   0.7378
# 468                 2               50  0.6575   0.6000
# 387                 5                5  0.6573   0.7568
# 429                 4               20  0.6570   0.7600
# 456                 3               50  0.6568   0.6604
# 223                 5               50  0.6567   0.6700
# 213                 2               50  0.6567   0.7403
# 354                 4               50  0.6564   0.7204
# 201                 3               20  0.6562   0.7004
# 471                 3               50  0.6559   0.7004
# 320                 2               20  0.6556   0.6944
# 45                  1               10  0.6553   0.6759
# 252                 5                5  0.6553   0.7781
# 132                 5                5  0.6553   0.6593
# 447                 5               20  0.6546   0.7403
# 313                 5               20  0.6546   0.6526
# 24                  4                5  0.6545   0.6593
# 428                 3               20  0.6542   0.5081
# 156                 3               10  0.6533   0.6800
# 288                 2               10  0.6530   0.6000
# 474                 4               50  0.6527   0.6604
# 165                 1               10  0.6522   0.7200
# 81                  3               20  0.6518   0.6000
# 168                 2               10  0.6517   0.6994
# 408                 2               10  0.6509   0.7600
# 311                 4               20  0.6509   0.6906
# 278                 3               10  0.6507   0.6960
# 441                 3               20  0.6506   0.6192
# 351                 3               50  0.6500   0.7600
# 162                 5               10  0.6495   0.7796
# 306                 3               20  0.6484   0.6785
# 21                  3                5  0.6483   0.6537
# 174                 4               10  0.6480   0.6800
# 435                 1               20  0.6477   0.6604
# 310                 4               20  0.6475   0.6700
# 264                 4                5  0.6469   0.6903
# 277                 3               10  0.6466   0.5842
# 459                 4               50  0.6457   0.6593
# 414                 4               10  0.6454   0.6785
# 51                  3               10  0.6449   0.5391
# 307                 3               20  0.6446   0.6436
# 171                 3               10  0.6442   0.7204
# 141                 3                5  0.6413   0.7004
# 318                 2               20  0.6411   0.7600
# 402                 5               10  0.6410   0.7200
# 378                 2                5  0.6395   0.6571
# 297                 5               10  0.6386   0.6353
# 294                 4               10  0.6382   0.6805
# 27                  5                5  0.6376   0.5900
# 324                 4               20  0.6355   0.6805
# 417                 5               10  0.6354   0.6400
# 15                  1                5  0.6349   0.7378
# 159                 4               10  0.6333   0.5765
# 391                 1               10  0.6322   0.6190
# 327                 5               20  0.6321   0.6312
# 138                 2                5  0.6292   0.6758
# 135                 1                5  0.6289   0.6537
# 381                 3                5  0.6277   0.5361
# 291                 3               10  0.6244   0.6593
# 384                 4                5  0.6197   0.7186
# 285                 1               10  0.6179   0.7403
# 144                 4                5  0.6160   0.6192
# 147                 5                5  0.6156   0.6759
# 396                 3               10  0.6090   0.6606
# 411                 3               10  0.6049   0.6131

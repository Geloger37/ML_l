# %% [markdown]
# # Начальная инициализация

# %%
import datetime
print(datetime.datetime.now().strftime('%d-%B-%Y %H:%M:%S'))
# Out:
# 26-May-2023 18:38:29

# %%
# Подключение библиотек

# !pip install torch torchvision torchaudio
# !pip install lightning
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data as data_utils
import lightning.pytorch as pl
import lightning as L

# !pip install scikit-learn
from sklearn.model_selection import ParameterGrid

import torch.optim as optim
# !pip install pandas
import pandas as pd
import numpy as np


import os
import random

# %%
random_state = 42

torch.use_deterministic_algorithms(True)

# %env CUBLAS_WORKSPACE_CONFIG=:4096:8
# %env PYTHONHASHSEED=42

def set_random_state(random_state):
    torch.manual_seed(random_state)
    random.seed(random_state)
    np.random.seed(random_state)

    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(random_state)
        torch.cuda.manual_seed(random_state)

        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False
        
set_random_state(random_state)

pl.seed_everything(random_state, workers=True)
# Out:
# Global seed set to 42
# env: CUBLAS_WORKSPACE_CONFIG=:4096:8
# env: PYTHONHASHSEED=42
# 42

# %%
print(datetime.datetime.now().strftime('%d-%B-%Y %H:%M:%S'))
# Out:
# 26-May-2023 18:38:39

# %% [markdown]
# # Обучение нейронных сетей

# %%
import pickle
PATH = 'dumps/'
with open(PATH + 'X_train_ft_pre_trained.pkl', mode='rb') as file:
    X_train_ft_pre_trained = pickle.load(file)

with open(PATH + 'X_train_w2v_pre_trained.pkl', mode='rb') as file:
    X_train_w2v_pre_trained = pickle.load(file)

with open(PATH + 'X_test_w2v_pre_trained.pkl', mode='rb') as file:
    X_test_w2v_pre_trained = pickle.load(file)

with open(PATH + 'X_test_w2v_self_trained.pkl', mode='rb') as file:
    X_test_w2v_self_trained = pickle.load(file)

with open(PATH + 'WordsIdPad_train.pkl', mode='rb') as file:
    WordsIdPad_train = pickle.load(file)

with open(PATH + 'X_test_ft_pre_trained.pkl', mode='rb') as file:
    X_test_ft_pre_trained = pickle.load(file)

with open(PATH + 'X_train_ft_self_trained.pkl', mode='rb') as file:
    X_train_ft_self_trained = pickle.load(file)

with open(PATH + 'WordsIdPad_test.pkl', mode='rb') as file:
    WordsIdPad_test = pickle.load(file)

with open(PATH + 'X_test_ft_self_trained.pkl', mode='rb') as file:
    X_test_ft_self_trained = pickle.load(file)

with open(PATH + 'X_train_w2v_self_trained.pkl', mode='rb') as file:
    X_train_w2v_self_trained = pickle.load(file)

with open(PATH + 'y_train.pkl', mode='rb') as file:
    y_train = pickle.load(file)

with open(PATH + 'y_test.pkl', mode='rb') as file:
    y_test = pickle.load(file)

# %%
param_grid = {
    "embeddings": ['w2v_pretrained', 'ft_pretrained', 'w2v_selftrained', 'ft_selftrained', 'torch.nn'],
    "conv_layers": [3],
    "activation_fn": [F.relu],
    "learning_rate": [0.001],
    "epochs": [5, 20],
    "batch_size": [2048],
    "optimizer": [optim.AdamW],
    "kernel_size": [3, 4],
    "stride": [1, 2],
    "layers_count": [1],
    "type_rnn": [torch.nn.RNN, torch.nn.LSTM, torch.nn.GRU],
    "hidden_size": [100],
    "bidirectional": [False, True],
    "initialization": [None, torch.nn.init.kaiming_uniform_, torch.nn.init.xavier_uniform_]
}

params_list = ParameterGrid(param_grid)
len(params_list)
# Out:
# 720

# %%
from sklearn.model_selection import train_test_split

class NetData(pl.LightningDataModule):
    def __init__(self, train_features=None, test_features=None, train_targets=None, test_targets=None, batch_size=None, random_state=None, internal=None):
        super().__init__()
        
        self.batch_size = batch_size
        self.X_train, self.X_val, self.y_train, self.y_val = train_test_split(train_features, train_targets, random_state=random_state)
        self.X_test, self.y_test = test_features, test_targets
        self.datatype = torch.int if internal else torch.float

    def setup(self, stage=None):

        features_train = torch.tensor(self.X_train, dtype=self.datatype)
        targets_train = torch.tensor(self.y_train, dtype=torch.int32)
    
        features_val = torch.tensor(self.X_val, dtype=self.datatype)
        targets_val = torch.tensor(self.y_val, dtype=torch.int32)
    
        features_test = torch.tensor(self.X_test, dtype=self.datatype)
        targets_test = torch.tensor(self.y_test, dtype=torch.int32)
    
        self.trainset = data_utils.TensorDataset(features_train, targets_train)
        self.valset = data_utils.TensorDataset(features_val, targets_val)
        self.testset = data_utils.TensorDataset(features_test, targets_test)
        
    def train_dataloader(self):
        return data_utils.DataLoader(self.trainset, batch_size=self.batch_size)
    def val_dataloader(self):
        return data_utils.DataLoader(self.valset, batch_size=self.batch_size)
    def test_dataloader(self):
        return data_utils.DataLoader(self.testset, batch_size=self.batch_size)

# %%
from torchmetrics.classification import F1Score

class Net(pl.LightningModule):
    def __init__(self,
                 layers_count=None, 
                 activation_function=None,
                 type_rnn=None,
                 hidden_size=None,
                 bidirectional=None,
                 optimizer=None,
                 learningRate=None,
                 internal=None,
                 conv_layers_count=None,
                 conv_kernel=None,
                 conv_stride=None,
                 initialization=None
                ):
        
        super().__init__()

        
        self.embedding_size = 300
        self.num_words = 10000
        self.seq_len = 20 if internal else 1
        self.optim = optimizer
        self.learningRate = learningRate

        self.f1 = F1Score(task='multiclass', num_classes=2, multidim_average='global', average='weighted')
        
        self.embedding = nn.Embedding(self.num_words + 1, self.embedding_size, padding_idx=0) if internal else None
        
        self.fa = activation_function

        output_shape = self.seq_len
        conv_padding = conv_kernel // 2
        self.conv_layers = nn.ModuleList()
        
        for i in range(conv_layers_count):
            self.conv_layers.append(nn.Conv1d(in_channels = self.embedding_size, out_channels = self.embedding_size, kernel_size = conv_kernel, stride = conv_stride, padding = conv_padding))
            output_shape = 1 + (output_shape + 2*conv_padding - conv_kernel) // conv_stride
        
        self.rnn = type_rnn(
                input_size = self.embedding_size,
                hidden_size = hidden_size,
                num_layers = layers_count,
                bidirectional = bidirectional,
                batch_first = True
        )
        
        self.fc = nn.Linear(hidden_size * output_shape * (1+bidirectional), 2)
        
        if initialization:
            self.iw(nn.Linear, initialization)
            self.iw(nn.Conv1d, initialization)
        

    def iw(self, ModuleClass, weights_initializator):
        for module in self.modules():
            if isinstance(module, ModuleClass):
                weights_initializator(module.weight)

    def forward(self, x):

        if self.embedding:
            x = self.embedding(x)
            x = x.reshape(len(x), self.embedding_size, self.seq_len)
        else:
            x = x[:, :, None]

        
        for layer in self.conv_layers:
            x = layer(x)
            x = self.fa(x)
        
        x = x.reshape(len(x), -1, self.embedding_size)

        x, size = self.rnn(x)

        x = self.fc(x.reshape(x.shape[0], -1))
        
        return F.log_softmax(x, dim=-1)
    
    def configure_optimizers(self):
        optimizer = self.optim(self.parameters(), lr=self.learningRate)
        return optimizer
    
    def training_step(self, batch, batch_idx):
        x, y = batch
        y_hat = self(x)
        loss = F.cross_entropy(y_hat, y.long())
        return loss
    
    def validation_step(self, batch, batch_idx):
        x, y = batch
        pred = self(x)
        self.log("val_f1", self.f1(pred, y), on_epoch=True)

    def test_step(self, batch, batch_idx):
        x, y = batch
        pred = self(x)
        self.log("test_f1", self.f1(pred, y), on_epoch=True)

# %%
from IPython.display import clear_output
from tqdm import tqdm
total = []

for params in tqdm(params_list):
    
    clear_output(wait=True)  

    learningRate = params['learning_rate']
    optimizer_type = params['optimizer']
    layers_count = params['layers_count']
    batch_size = params['batch_size']
    epochs = params['epochs']
    fa = params['activation_fn']
    type_rnn = params['type_rnn']
    hidden_size = params['hidden_size']
    bidirectional = params['bidirectional']
    conv_layers_count = params['conv_layers']
    embeddings = params['embeddings']
    kernel_size = params['kernel_size']
    stride = params['stride']
    initialization = params['initialization']


    net = Net(
        layers_count=layers_count,
        activation_function=fa,
        type_rnn=type_rnn,
        hidden_size=hidden_size,
        bidirectional=bidirectional,
        optimizer=optimizer_type,
        learningRate=learningRate,
        conv_kernel=kernel_size,
        conv_layers_count=conv_layers_count,
        conv_stride=stride,
        internal=(embeddings=='torch.nn'),
        initialization=initialization
        )
    dm = None
    if embeddings == 'w2v_pretrained':
        dm = NetData(
            train_features=X_train_w2v_pre_trained,
            test_features=X_test_w2v_pre_trained,
            train_targets=y_train,
            test_targets=y_test,
            batch_size=batch_size,
            random_state=random_state,
            internal=(embeddings=='torch.nn')
        )
    elif embeddings == 'w2v_selftrained':
        dm = NetData(
            train_features=X_train_w2v_self_trained,
            test_features=X_test_w2v_self_trained,
            train_targets=y_train,
            test_targets=y_test,
            batch_size=batch_size,
            random_state=random_state,
            internal=(embeddings=='torch.nn')
        )
    elif embeddings == 'ft_pretrained':
        dm = NetData(
            train_features=X_train_ft_pre_trained,
            test_features=X_test_ft_pre_trained,
            train_targets=y_train,
            test_targets=y_test,
            batch_size=batch_size,
            random_state=random_state,
            internal=(embeddings=='torch.nn')
        )
    elif embeddings == 'ft_selftrained':
        dm = NetData(
            train_features=X_train_ft_self_trained,
            test_features=X_test_ft_self_trained,
            train_targets=y_train,
            test_targets=y_test,
            batch_size=batch_size,
            random_state=random_state,
            internal=(embeddings=='torch.nn')
        )
    elif embeddings == 'torch.nn':
        dm = NetData(
            train_features=WordsIdPad_train,
            test_features=WordsIdPad_test,
            train_targets=y_train,
            test_targets=y_test,
            batch_size=batch_size,
            random_state=random_state,
            internal=(embeddings=='torch.nn')
        )
        
    trainer = L.Trainer(logger=False, max_epochs=epochs, enable_progress_bar=True, deterministic=True, inference_mode=True, enable_checkpointing=False)
    trainer.fit(net, datamodule=dm)
    f1_val = trainer.validate(net, datamodule=dm)[-1]['val_f1']
    f1_test = trainer.test(net, datamodule=dm)[-1]['test_f1']
    
    total.append({
        'embeddings': embeddings,
        'kernel_size': kernel_size,
        'stride': stride,
        'conv layers': conv_layers_count,
        'Type RNN': type_rnn.__name__,
        'hidden_size': hidden_size,
        'bidirectional': bidirectional,
        'rrn layers': layers_count,
        'optimizer': optimizer_type.__name__,
        'lr': learningRate,
        'epochs': epochs,
        'batch_size': batch_size,
        'initialization': initialization.__name__ if initialization else None,
        'F1-val': round(f1_val, 4),
        'F1-test': round(f1_test, 4)
    })
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name        | Type              | Params
# --------------------------------------------------
# 0 | f1          | MulticlassF1Score | 0
# 1 | embedding   | Embedding         | 3.0 M
# 2 | conv_layers | ModuleList        | 1.1 M
# 3 | rnn         | GRU               | 241 K
# 4 | fc          | Linear            | 1.6 K
# --------------------------------------------------
# 4.3 M     Trainable params
# 0         Non-trainable params
# 4.3 M     Total params
# 17.296    Total estimated model params size (MB)
# Epoch 19: 100%|██████████| 9/9 [00:00<00:00, 10.52it/s]
# `Trainer.fit` stopped: `max_epochs=20` reached.
# Epoch 19: 100%|██████████| 9/9 [00:00<00:00, 10.51it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 51.24it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃  Runningstage.validating  ┃                           ┃
# ┃          metric           ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │          val_f1           │    0.6454423069953918     │
# └───────────────────────────┴───────────────────────────┘
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 171.48it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃   Runningstage.testing    ┃                           ┃
# ┃          metric           ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │          test_f1          │    0.7403120994567871     │
# └───────────────────────────┴───────────────────────────┘
# 100%|██████████| 720/720 [1:02:09<00:00,  5.18s/it]

# %%
print(datetime.datetime.now().strftime('%d-%B-%Y %H:%M:%S'))
# Out:
# 26-May-2023 18:38:43

# %% [markdown]
# # Сводная таблица

# %%
pd.set_option('display.max_rows', None)
summary = pd.DataFrame.from_dict(total)
summary_sort = summary.sort_values(by='F1-val', ascending=False)
summary_sort
# Out:
#           embeddings  kernel_size  stride  conv layers Type RNN  hidden_size  \
# 621   ft_selftrained            4       2            3      RNN          100
# 613   ft_selftrained            3       1            3     LSTM          100
# 256   ft_selftrained            3       2            3     LSTM          100
# 614   ft_selftrained            3       1            3      GRU          100
# 595   ft_selftrained            4       1            3     LSTM          100
# 616   ft_selftrained            3       2            3     LSTM          100
# 263   ft_selftrained            4       2            3      GRU          100
# 286   ft_selftrained            4       2            3     LSTM          100
# 606   ft_selftrained            4       1            3      RNN          100
# 255   ft_selftrained            3       2            3      RNN          100
# 600   ft_selftrained            3       1            3      RNN          100
# 225   ft_selftrained            4       2            3      RNN          100
# 231   ft_selftrained            3       2            3      RNN          100
# 287   ft_selftrained            4       2            3      GRU          100
# 234   ft_selftrained            4       1            3      RNN          100
# 605   ft_selftrained            3       2            3      GRU          100
# 622   ft_selftrained            4       2            3     LSTM          100
# 232   ft_selftrained            3       2            3     LSTM          100
# 262   ft_selftrained            4       2            3     LSTM          100
# 278   ft_selftrained            3       1            3      GRU          100
# 615   ft_selftrained            3       2            3      RNN          100
# 240   ft_selftrained            3       1            3      RNN          100
# 611   ft_selftrained            4       2            3      GRU          100
# 584   ft_selftrained            4       1            3      GRU          100
# 617   ft_selftrained            3       2            3      GRU          100
# 251   ft_selftrained            4       2            3      GRU          100
# 164  w2v_selftrained            4       1            3      GRU          100
# 253   ft_selftrained            3       1            3     LSTM          100
# 233   ft_selftrained            3       2            3      GRU          100
# 608   ft_selftrained            4       1            3      GRU          100
# 216   ft_selftrained            3       1            3      RNN          100
# 238   ft_selftrained            4       2            3     LSTM          100
# 549  w2v_selftrained            4       2            3      RNN          100
# 237   ft_selftrained            4       2            3      RNN          100
# 245   ft_selftrained            3       2            3      GRU          100
# 607   ft_selftrained            4       1            3     LSTM          100
# 619   ft_selftrained            4       1            3     LSTM          100
# 612   ft_selftrained            3       1            3      RNN          100
# 590   ft_selftrained            3       1            3      GRU          100
# 257   ft_selftrained            3       2            3      GRU          100
# 248   ft_selftrained            4       1            3      GRU          100
# 525  w2v_selftrained            4       2            3      RNN          100
# 236   ft_selftrained            4       1            3      GRU          100
# 593   ft_selftrained            3       2            3      GRU          100
# 582   ft_selftrained            4       1            3      RNN          100
# 583   ft_selftrained            4       1            3     LSTM          100
# 637   ft_selftrained            3       1            3     LSTM          100
# 604   ft_selftrained            3       2            3     LSTM          100
# 610   ft_selftrained            4       2            3     LSTM          100
# 609   ft_selftrained            4       2            3      RNN          100
# 223   ft_selftrained            4       1            3     LSTM          100
# 176  w2v_selftrained            4       1            3      GRU          100
# 270   ft_selftrained            4       1            3      RNN          100
# 228   ft_selftrained            3       1            3      RNN          100
# 589   ft_selftrained            3       1            3     LSTM          100
# 242   ft_selftrained            3       1            3      GRU          100
# 522  w2v_selftrained            4       1            3      RNN          100
# 159  w2v_selftrained            3       2            3      RNN          100
# 261   ft_selftrained            4       2            3      RNN          100
# 241   ft_selftrained            3       1            3     LSTM          100
# 521  w2v_selftrained            3       2            3      GRU          100
# 171  w2v_selftrained            3       2            3      RNN          100
# 576   ft_selftrained            3       1            3      RNN          100
# 230   ft_selftrained            3       1            3      GRU          100
# 602   ft_selftrained            3       1            3      GRU          100
# 244   ft_selftrained            3       2            3     LSTM          100
# 229   ft_selftrained            3       1            3     LSTM          100
# 246   ft_selftrained            4       1            3      RNN          100
# 519  w2v_selftrained            3       2            3      RNN          100
# 536  w2v_selftrained            4       1            3      GRU          100
# 168  w2v_selftrained            3       1            3      RNN          100
# 597   ft_selftrained            4       2            3      RNN          100
# 150  w2v_selftrained            4       1            3      RNN          100
# 603   ft_selftrained            3       2            3      RNN          100
# 535  w2v_selftrained            4       1            3     LSTM          100
# 222   ft_selftrained            4       1            3      RNN          100
# 592   ft_selftrained            3       2            3     LSTM          100
# 518  w2v_selftrained            3       1            3      GRU          100
# 221   ft_selftrained            3       2            3      GRU          100
# 577   ft_selftrained            3       1            3     LSTM          100
# 219   ft_selftrained            3       2            3      RNN          100
# 632   ft_selftrained            4       1            3      GRU          100
# 510  w2v_selftrained            4       1            3      RNN          100
# 249   ft_selftrained            4       2            3      RNN          100
# 591   ft_selftrained            3       2            3      RNN          100
# 601   ft_selftrained            3       1            3     LSTM          100
# 528  w2v_selftrained            3       1            3      RNN          100
# 254   ft_selftrained            3       1            3      GRU          100
# 512  w2v_selftrained            4       1            3      GRU          100
# 227   ft_selftrained            4       2            3      GRU          100
# 165  w2v_selftrained            4       2            3      RNN          100
# 524  w2v_selftrained            4       1            3      GRU          100
# 581   ft_selftrained            3       2            3      GRU          100
# 523  w2v_selftrained            4       1            3     LSTM          100
# 530  w2v_selftrained            3       1            3      GRU          100
# 585   ft_selftrained            4       2            3      RNN          100
# 147  w2v_selftrained            3       2            3      RNN          100
# 217   ft_selftrained            3       1            3     LSTM          100
# 173  w2v_selftrained            3       2            3      GRU          100
# 517  w2v_selftrained            3       1            3     LSTM          100
# 163  w2v_selftrained            4       1            3     LSTM          100
# 599   ft_selftrained            4       2            3      GRU          100
# 507  w2v_selftrained            3       2            3      RNN          100
# 533  w2v_selftrained            3       2            3      GRU          100
# 169  w2v_selftrained            3       1            3     LSTM          100
# 218   ft_selftrained            3       1            3      GRU          100
# 526  w2v_selftrained            4       2            3     LSTM          100
# 224   ft_selftrained            4       1            3      GRU          100
# 588   ft_selftrained            3       1            3      RNN          100
# 172  w2v_selftrained            3       2            3     LSTM          100
# 268   ft_selftrained            3       2            3     LSTM          100
# 167  w2v_selftrained            4       2            3      GRU          100
# 508  w2v_selftrained            3       2            3     LSTM          100
# 281   ft_selftrained            3       2            3      GRU          100
# 181  w2v_selftrained            3       1            3     LSTM          100
# 594   ft_selftrained            4       1            3      RNN          100
# 182  w2v_selftrained            3       1            3      GRU          100
# 226   ft_selftrained            4       2            3     LSTM          100
# 162  w2v_selftrained            4       1            3      RNN          100
# 158  w2v_selftrained            3       1            3      GRU          100
# 537  w2v_selftrained            4       2            3      RNN          100
# 214  w2v_selftrained            4       2            3     LSTM          100
# 504  w2v_selftrained            3       1            3      RNN          100
# 516  w2v_selftrained            3       1            3      RNN          100
# 178  w2v_selftrained            4       2            3     LSTM          100
# 534  w2v_selftrained            4       1            3      RNN          100
# 174  w2v_selftrained            4       1            3      RNN          100
# 539  w2v_selftrained            4       2            3      GRU          100
# 531  w2v_selftrained            3       2            3      RNN          100
# 596   ft_selftrained            4       1            3      GRU          100
# 532  w2v_selftrained            3       2            3     LSTM          100
# 239   ft_selftrained            4       2            3      GRU          100
# 538  w2v_selftrained            4       2            3     LSTM          100
# 175  w2v_selftrained            4       1            3     LSTM          100
# 274   ft_selftrained            4       2            3     LSTM          100
# 551  w2v_selftrained            4       2            3      GRU          100
# 579   ft_selftrained            3       2            3      RNN          100
# 179  w2v_selftrained            4       2            3      GRU          100
# 574  w2v_selftrained            4       2            3     LSTM          100
# 161  w2v_selftrained            3       2            3      GRU          100
# 235   ft_selftrained            4       1            3     LSTM          100
# 520  w2v_selftrained            3       2            3     LSTM          100
# 151  w2v_selftrained            4       1            3     LSTM          100
# 205  w2v_selftrained            3       1            3     LSTM          100
# 247   ft_selftrained            4       1            3     LSTM          100
# 189  w2v_selftrained            4       2            3      RNN          100
# 157  w2v_selftrained            3       1            3     LSTM          100
# 540  w2v_selftrained            3       1            3      RNN          100
# 598   ft_selftrained            4       2            3     LSTM          100
# 527  w2v_selftrained            4       2            3      GRU          100
# 529  w2v_selftrained            3       1            3     LSTM          100
# 515  w2v_selftrained            4       2            3      GRU          100
# 153  w2v_selftrained            4       2            3      RNN          100
# 547  w2v_selftrained            4       1            3     LSTM          100
# 514  w2v_selftrained            4       2            3     LSTM          100
# 243   ft_selftrained            3       2            3      RNN          100
# 160  w2v_selftrained            3       2            3     LSTM          100
# 213  w2v_selftrained            4       2            3      RNN          100
# 146  w2v_selftrained            3       1            3      GRU          100
# 509  w2v_selftrained            3       2            3      GRU          100
# 200  w2v_selftrained            4       1            3      GRU          100
# 154  w2v_selftrained            4       2            3     LSTM          100
# 511  w2v_selftrained            4       1            3     LSTM          100
# 190  w2v_selftrained            4       2            3     LSTM          100
# 156  w2v_selftrained            3       1            3      RNN          100
# 280   ft_selftrained            3       2            3     LSTM          100
# 513  w2v_selftrained            4       2            3      RNN          100
# 220   ft_selftrained            3       2            3     LSTM          100
# 145  w2v_selftrained            3       1            3     LSTM          100
# 215  w2v_selftrained            4       2            3      GRU          100
# 506  w2v_selftrained            3       1            3      GRU          100
# 252   ft_selftrained            3       1            3      RNN          100
# 152  w2v_selftrained            4       1            3      GRU          100
# 568  w2v_selftrained            3       2            3     LSTM          100
# 634   ft_selftrained            4       2            3     LSTM          100
# 177  w2v_selftrained            4       2            3      RNN          100
# 562  w2v_selftrained            4       2            3     LSTM          100
# 541  w2v_selftrained            3       1            3     LSTM          100
# 148  w2v_selftrained            3       2            3     LSTM          100
# 170  w2v_selftrained            3       1            3      GRU          100
# 149  w2v_selftrained            3       2            3      GRU          100
# 646   ft_selftrained            4       2            3     LSTM          100
# 580   ft_selftrained            3       2            3     LSTM          100
# 643   ft_selftrained            4       1            3     LSTM          100
# 628   ft_selftrained            3       2            3     LSTM          100
# 553  w2v_selftrained            3       1            3     LSTM          100
# 578   ft_selftrained            3       1            3      GRU          100
# 285   ft_selftrained            4       2            3      RNN          100
# 202  w2v_selftrained            4       2            3     LSTM          100
# 586   ft_selftrained            4       2            3     LSTM          100
# 180  w2v_selftrained            3       1            3      RNN          100
# 194  w2v_selftrained            3       1            3      GRU          100
# 543  w2v_selftrained            3       2            3      RNN          100
# 641   ft_selftrained            3       2            3      GRU          100
# 155  w2v_selftrained            4       2            3      GRU          100
# 258   ft_selftrained            4       1            3      RNN          100
# 144  w2v_selftrained            3       1            3      RNN          100
# 267   ft_selftrained            3       2            3      RNN          100
# 544  w2v_selftrained            3       2            3     LSTM          100
# 250   ft_selftrained            4       2            3     LSTM          100
# 193  w2v_selftrained            3       1            3     LSTM          100
# 575  w2v_selftrained            4       2            3      GRU          100
# 572  w2v_selftrained            4       1            3      GRU          100
# 636   ft_selftrained            3       1            3      RNN          100
# 203  w2v_selftrained            4       2            3      GRU          100
# 505  w2v_selftrained            3       1            3     LSTM          100
# 618   ft_selftrained            4       1            3      RNN          100
# 166  w2v_selftrained            4       2            3     LSTM          100
# 640   ft_selftrained            3       2            3     LSTM          100
# 259   ft_selftrained            4       1            3     LSTM          100
# 279   ft_selftrained            3       2            3      RNN          100
# 542  w2v_selftrained            3       1            3      GRU          100
# 548  w2v_selftrained            4       1            3      GRU          100
# 642   ft_selftrained            4       1            3      RNN          100
# 623   ft_selftrained            4       2            3      GRU          100
# 587   ft_selftrained            4       2            3      GRU          100
# 277   ft_selftrained            3       1            3     LSTM          100
# 269   ft_selftrained            3       2            3      GRU          100
# 566  w2v_selftrained            3       1            3      GRU          100
# 212  w2v_selftrained            4       1            3      GRU          100
# 195  w2v_selftrained            3       2            3      RNN          100
# 209  w2v_selftrained            3       2            3      GRU          100
# 633   ft_selftrained            4       2            3      RNN          100
# 645   ft_selftrained            4       2            3      RNN          100
# 571  w2v_selftrained            4       1            3     LSTM          100
# 644   ft_selftrained            4       1            3      GRU          100
# 199  w2v_selftrained            4       1            3     LSTM          100
# 185  w2v_selftrained            3       2            3      GRU          100
# 638   ft_selftrained            3       1            3      GRU          100
# 546  w2v_selftrained            4       1            3      RNN          100
# 208  w2v_selftrained            3       2            3     LSTM          100
# 191  w2v_selftrained            4       2            3      GRU          100
# 554  w2v_selftrained            3       1            3      GRU          100
# 629   ft_selftrained            3       2            3      GRU          100
# 557  w2v_selftrained            3       2            3      GRU          100
# 196  w2v_selftrained            3       2            3     LSTM          100
# 275   ft_selftrained            4       2            3      GRU          100
# 197  w2v_selftrained            3       2            3      GRU          100
# 635   ft_selftrained            4       2            3      GRU          100
# 198  w2v_selftrained            4       1            3      RNN          100
# 564  w2v_selftrained            3       1            3      RNN          100
# 626   ft_selftrained            3       1            3      GRU          100
# 283   ft_selftrained            4       1            3     LSTM          100
# 561  w2v_selftrained            4       2            3      RNN          100
# 545  w2v_selftrained            3       2            3      GRU          100
# 552  w2v_selftrained            3       1            3      RNN          100
# 625   ft_selftrained            3       1            3     LSTM          100
# 380   w2v_pretrained            4       1            3      GRU          100
# 555  w2v_selftrained            3       2            3      RNN          100
# 272   ft_selftrained            4       1            3      GRU          100
# 188  w2v_selftrained            4       1            3      GRU          100
# 282   ft_selftrained            4       1            3      RNN          100
# 206  w2v_selftrained            3       1            3      GRU          100
# 276   ft_selftrained            3       1            3      RNN          100
# 266   ft_selftrained            3       1            3      GRU          100
# 569  w2v_selftrained            3       2            3      GRU          100
# 378   w2v_pretrained            4       1            3      RNN          100
# 372   w2v_pretrained            3       1            3      RNN          100
# 624   ft_selftrained            3       1            3      RNN          100
# 91     ft_pretrained            4       1            3     LSTM          100
# 27    w2v_pretrained            3       2            3      RNN          100
# 565  w2v_selftrained            3       1            3     LSTM          100
# 373   w2v_pretrained            3       1            3     LSTM          100
# 24    w2v_pretrained            3       1            3      RNN          100
# 31    w2v_pretrained            4       1            3     LSTM          100
# 379   w2v_pretrained            4       1            3     LSTM          100
# 458    ft_pretrained            3       1            3      GRU          100
# 12    w2v_pretrained            3       1            3      RNN          100
# 366   w2v_pretrained            4       1            3      RNN          100
# 647   ft_selftrained            4       2            3      GRU          100
# 89     ft_pretrained            3       2            3      GRU          100
# 84     ft_pretrained            3       1            3      RNN          100
# 450    ft_pretrained            4       1            3      RNN          100
# 20    w2v_pretrained            4       1            3      GRU          100
# 30    w2v_pretrained            4       1            3      RNN          100
# 22    w2v_pretrained            4       2            3     LSTM          100
# 392   w2v_pretrained            4       1            3      GRU          100
# 620   ft_selftrained            4       1            3      GRU          100
# 273   ft_selftrained            4       2            3      RNN          100
# 6     w2v_pretrained            4       1            3      RNN          100
# 381   w2v_pretrained            4       2            3      RNN          100
# 17    w2v_pretrained            3       2            3      GRU          100
# 383   w2v_pretrained            4       2            3      GRU          100
# 265   ft_selftrained            3       1            3     LSTM          100
# 462    ft_pretrained            4       1            3      RNN          100
# 387   w2v_pretrained            3       2            3      RNN          100
# 211  w2v_selftrained            4       1            3     LSTM          100
# 19    w2v_pretrained            4       1            3     LSTM          100
# 104    ft_pretrained            4       1            3      GRU          100
# 631   ft_selftrained            4       1            3     LSTM          100
# 444    ft_pretrained            3       1            3      RNN          100
# 21    w2v_pretrained            4       2            3      RNN          100
# 80     ft_pretrained            4       1            3      GRU          100
# 461    ft_pretrained            3       2            3      GRU          100
# 391   w2v_pretrained            4       1            3     LSTM          100
# 467    ft_pretrained            4       2            3      GRU          100
# 192  w2v_selftrained            3       1            3      RNN          100
# 99     ft_pretrained            3       2            3      RNN          100
# 90     ft_pretrained            4       1            3      RNN          100
# 389   w2v_pretrained            3       2            3      GRU          100
# 456    ft_pretrained            3       1            3      RNN          100
# 32    w2v_pretrained            4       1            3      GRU          100
# 550  w2v_selftrained            4       2            3     LSTM          100
# 376   w2v_pretrained            3       2            3     LSTM          100
# 87     ft_pretrained            3       2            3      RNN          100
# 102    ft_pretrained            4       1            3      RNN          100
# 29    w2v_pretrained            3       2            3      GRU          100
# 449    ft_pretrained            3       2            3      GRU          100
# 439    ft_pretrained            4       1            3     LSTM          100
# 105    ft_pretrained            4       2            3      RNN          100
# 453    ft_pretrained            4       2            3      RNN          100
# 103    ft_pretrained            4       1            3     LSTM          100
# 438    ft_pretrained            4       1            3      RNN          100
# 136    ft_pretrained            3       2            3     LSTM          100
# 447    ft_pretrained            3       2            3      RNN          100
# 451    ft_pretrained            4       1            3     LSTM          100
# 367   w2v_pretrained            4       1            3     LSTM          100
# 86     ft_pretrained            3       1            3      GRU          100
# 187  w2v_selftrained            4       1            3     LSTM          100
# 25    w2v_pretrained            3       1            3     LSTM          100
# 393   w2v_pretrained            4       2            3      RNN          100
# 465    ft_pretrained            4       2            3      RNN          100
# 18    w2v_pretrained            4       1            3      RNN          100
# 374   w2v_pretrained            3       1            3      GRU          100
# 23    w2v_pretrained            4       2            3      GRU          100
# 100    ft_pretrained            3       2            3     LSTM          100
# 93     ft_pretrained            4       2            3      RNN          100
# 457    ft_pretrained            3       1            3     LSTM          100
# 8     w2v_pretrained            4       1            3      GRU          100
# 432    ft_pretrained            3       1            3      RNN          100
# 78     ft_pretrained            4       1            3      RNN          100
# 390   w2v_pretrained            4       1            3      RNN          100
# 435    ft_pretrained            3       2            3      RNN          100
# 98     ft_pretrained            3       1            3      GRU          100
# 377   w2v_pretrained            3       2            3      GRU          100
# 107    ft_pretrained            4       2            3      GRU          100
# 75     ft_pretrained            3       2            3      RNN          100
# 106    ft_pretrained            4       2            3     LSTM          100
# 0     w2v_pretrained            3       1            3      RNN          100
# 466    ft_pretrained            4       2            3     LSTM          100
# 79     ft_pretrained            4       1            3     LSTM          100
# 34    w2v_pretrained            4       2            3     LSTM          100
# 16    w2v_pretrained            3       2            3     LSTM          100
# 26    w2v_pretrained            3       1            3      GRU          100
# 360   w2v_pretrained            3       1            3      RNN          100
# 2     w2v_pretrained            3       1            3      GRU          100
# 204  w2v_selftrained            3       1            3      RNN          100
# 94     ft_pretrained            4       2            3     LSTM          100
# 382   w2v_pretrained            4       2            3     LSTM          100
# 77     ft_pretrained            3       2            3      GRU          100
# 445    ft_pretrained            3       1            3     LSTM          100
# 35    w2v_pretrained            4       2            3      GRU          100
# 394   w2v_pretrained            4       2            3     LSTM          100
# 440    ft_pretrained            4       1            3      GRU          100
# 573  w2v_selftrained            4       2            3      RNN          100
# 437    ft_pretrained            3       2            3      GRU          100
# 362   w2v_pretrained            3       1            3      GRU          100
# 464    ft_pretrained            4       1            3      GRU          100
# 369   w2v_pretrained            4       2            3      RNN          100
# 446    ft_pretrained            3       1            3      GRU          100
# 388   w2v_pretrained            3       2            3     LSTM          100
# 368   w2v_pretrained            4       1            3      GRU          100
# 448    ft_pretrained            3       2            3     LSTM          100
# 371   w2v_pretrained            4       2            3      GRU          100
# 560  w2v_selftrained            4       1            3      GRU          100
# 28    w2v_pretrained            3       2            3     LSTM          100
# 33    w2v_pretrained            4       2            3      RNN          100
# 384   w2v_pretrained            3       1            3      RNN          100
# 441    ft_pretrained            4       2            3      RNN          100
# 88     ft_pretrained            3       2            3     LSTM          100
# 434    ft_pretrained            3       1            3      GRU          100
# 81     ft_pretrained            4       2            3      RNN          100
# 443    ft_pretrained            4       2            3      GRU          100
# 101    ft_pretrained            3       2            3      GRU          100
# 284   ft_selftrained            4       1            3      GRU          100
# 201  w2v_selftrained            4       2            3      RNN          100
# 15    w2v_pretrained            3       2            3      RNN          100
# 455    ft_pretrained            4       2            3      GRU          100
# 385   w2v_pretrained            3       1            3     LSTM          100
# 7     w2v_pretrained            4       1            3     LSTM          100
# 460    ft_pretrained            3       2            3     LSTM          100
# 386   w2v_pretrained            3       1            3      GRU          100
# 463    ft_pretrained            4       1            3     LSTM          100
# 74     ft_pretrained            3       1            3      GRU          100
# 356         torch.nn            4       1            3      GRU          100
# 639   ft_selftrained            3       2            3      RNN          100
# 9     w2v_pretrained            4       2            3      RNN          100
# 184  w2v_selftrained            3       2            3     LSTM          100
# 452    ft_pretrained            4       1            3      GRU          100
# 365   w2v_pretrained            3       2            3      GRU          100
# 95     ft_pretrained            4       2            3      GRU          100
# 97     ft_pretrained            3       1            3     LSTM          100
# 370   w2v_pretrained            4       2            3     LSTM          100
# 92     ft_pretrained            4       1            3      GRU          100
# 85     ft_pretrained            3       1            3     LSTM          100
# 11    w2v_pretrained            4       2            3      GRU          100
# 494    ft_pretrained            3       1            3      GRU          100
# 1     w2v_pretrained            3       1            3     LSTM          100
# 83     ft_pretrained            4       2            3      GRU          100
# 442    ft_pretrained            4       2            3     LSTM          100
# 436    ft_pretrained            3       2            3     LSTM          100
# 76     ft_pretrained            3       2            3     LSTM          100
# 96     ft_pretrained            3       1            3      RNN          100
# 363   w2v_pretrained            3       2            3      RNN          100
# 82     ft_pretrained            4       2            3     LSTM          100
# 559  w2v_selftrained            4       1            3     LSTM          100
# 5     w2v_pretrained            3       2            3      GRU          100
# 14    w2v_pretrained            3       1            3      GRU          100
# 13    w2v_pretrained            3       1            3     LSTM          100
# 627   ft_selftrained            3       2            3      RNN          100
# 72     ft_pretrained            3       1            3      RNN          100
# 361   w2v_pretrained            3       1            3     LSTM          100
# 375   w2v_pretrained            3       2            3      RNN          100
# 137    ft_pretrained            3       2            3      GRU          100
# 73     ft_pretrained            3       1            3     LSTM          100
# 364   w2v_pretrained            3       2            3     LSTM          100
# 421   w2v_pretrained            3       1            3     LSTM          100
# 454    ft_pretrained            4       2            3     LSTM          100
# 556  w2v_selftrained            3       2            3     LSTM          100
# 3     w2v_pretrained            3       2            3      RNN          100
# 10    w2v_pretrained            4       2            3     LSTM          100
# 478    ft_pretrained            4       2            3     LSTM          100
# 120    ft_pretrained            3       1            3      RNN          100
# 399   w2v_pretrained            3       2            3      RNN          100
# 459    ft_pretrained            3       2            3      RNN          100
# 260   ft_selftrained            4       1            3      GRU          100
# 395   w2v_pretrained            4       2            3      GRU          100
# 4     w2v_pretrained            3       2            3     LSTM          100
# 686         torch.nn            3       1            3      GRU          100
# 715         torch.nn            4       1            3     LSTM          100
# 69    w2v_pretrained            4       2            3      RNN          100
# 470    ft_pretrained            3       1            3      GRU          100
# 398   w2v_pretrained            3       1            3      GRU          100
# 692         torch.nn            4       1            3      GRU          100
# 433    ft_pretrained            3       1            3     LSTM          100
# 142    ft_pretrained            4       2            3     LSTM          100
# 111    ft_pretrained            3       2            3      RNN          100
# 36    w2v_pretrained            3       1            3      RNN          100
# 41    w2v_pretrained            3       2            3      GRU          100
# 121    ft_pretrained            3       1            3     LSTM          100
# 119    ft_pretrained            4       2            3      GRU          100
# 404   w2v_pretrained            4       1            3      GRU          100
# 406   w2v_pretrained            4       2            3     LSTM          100
# 64    w2v_pretrained            3       2            3     LSTM          100
# 109    ft_pretrained            3       1            3     LSTM          100
# 410   w2v_pretrained            3       1            3      GRU          100
# 38    w2v_pretrained            3       1            3      GRU          100
# 68    w2v_pretrained            4       1            3      GRU          100
# 417   w2v_pretrained            4       2            3      RNN          100
# 62    w2v_pretrained            3       1            3      GRU          100
# 118    ft_pretrained            4       2            3     LSTM          100
# 271   ft_selftrained            4       1            3     LSTM          100
# 132    ft_pretrained            3       1            3      RNN          100
# 47    w2v_pretrained            4       2            3      GRU          100
# 501    ft_pretrained            4       2            3      RNN          100
# 114    ft_pretrained            4       1            3      RNN          100
# 479    ft_pretrained            4       2            3      GRU          100
# 673         torch.nn            3       1            3     LSTM          100
# 567  w2v_selftrained            3       2            3      RNN          100
# 714         torch.nn            4       1            3      RNN          100
# 138    ft_pretrained            4       1            3      RNN          100
# 709         torch.nn            3       1            3     LSTM          100
# 415   w2v_pretrained            4       1            3     LSTM          100
# 183  w2v_selftrained            3       2            3      RNN          100
# 342         torch.nn            4       1            3      RNN          100
# 61    w2v_pretrained            3       1            3     LSTM          100
# 690         torch.nn            4       1            3      RNN          100
# 713         torch.nn            3       2            3      GRU          100
# 40    w2v_pretrained            3       2            3     LSTM          100
# 471    ft_pretrained            3       2            3      RNN          100
# 412   w2v_pretrained            3       2            3     LSTM          100
# 37    w2v_pretrained            3       1            3     LSTM          100
# 354         torch.nn            4       1            3      RNN          100
# 133    ft_pretrained            3       1            3     LSTM          100
# 324         torch.nn            3       1            3      RNN          100
# 50    w2v_pretrained            3       1            3      GRU          100
# 127    ft_pretrained            4       1            3     LSTM          100
# 495    ft_pretrained            3       2            3      RNN          100
# 469    ft_pretrained            3       1            3     LSTM          100
# 207  w2v_selftrained            3       2            3      RNN          100
# 57    w2v_pretrained            4       2            3      RNN          100
# 468    ft_pretrained            3       1            3      RNN          100
# 409   w2v_pretrained            3       1            3     LSTM          100
# 490    ft_pretrained            4       2            3     LSTM          100
# 431   w2v_pretrained            4       2            3      GRU          100
# 331         torch.nn            4       1            3     LSTM          100
# 685         torch.nn            3       1            3     LSTM          100
# 503    ft_pretrained            4       2            3      GRU          100
# 474    ft_pretrained            4       1            3      RNN          100
# 330         torch.nn            4       1            3      RNN          100
# 59    w2v_pretrained            4       2            3      GRU          100
# 46    w2v_pretrained            4       2            3     LSTM          100
# 687         torch.nn            3       2            3      RNN          100
# 691         torch.nn            4       1            3     LSTM          100
# 719         torch.nn            4       2            3      GRU          100
# 334         torch.nn            4       2            3     LSTM          100
# 66    w2v_pretrained            4       1            3      RNN          100
# 706         torch.nn            4       2            3     LSTM          100
# 480    ft_pretrained            3       1            3      RNN          100
# 113    ft_pretrained            3       2            3      GRU          100
# 716         torch.nn            4       1            3      GRU          100
# 411   w2v_pretrained            3       2            3      RNN          100
# 350         torch.nn            3       1            3      GRU          100
# 344         torch.nn            4       1            3      GRU          100
# 704         torch.nn            4       1            3      GRU          100
# 697         torch.nn            3       1            3     LSTM          100
# 397   w2v_pretrained            3       1            3     LSTM          100
# 418   w2v_pretrained            4       2            3     LSTM          100
# 484    ft_pretrained            3       2            3     LSTM          100
# 332         torch.nn            4       1            3      GRU          100
# 54    w2v_pretrained            4       1            3      RNN          100
# 343         torch.nn            4       1            3     LSTM          100
# 698         torch.nn            3       1            3      GRU          100
# 683         torch.nn            4       2            3      GRU          100
# 359         torch.nn            4       2            3      GRU          100
# 695         torch.nn            4       2            3      GRU          100
# 264   ft_selftrained            3       1            3      RNN          100
# 405   w2v_pretrained            4       2            3      RNN          100
# 323         torch.nn            4       2            3      GRU          100
# 325         torch.nn            3       1            3     LSTM          100
# 491    ft_pretrained            4       2            3      GRU          100
# 488    ft_pretrained            4       1            3      GRU          100
# 401   w2v_pretrained            3       2            3      GRU          100
# 654         torch.nn            4       1            3      RNN          100
# 320         torch.nn            4       1            3      GRU          100
# 326         torch.nn            3       1            3      GRU          100
# 115    ft_pretrained            4       1            3     LSTM          100
# 337         torch.nn            3       1            3     LSTM          100
# 318         torch.nn            4       1            3      RNN          100
# 413   w2v_pretrained            3       2            3      GRU          100
# 348         torch.nn            3       1            3      RNN          100
# 327         torch.nn            3       2            3      RNN          100
# 656         torch.nn            4       1            3      GRU          100
# 358         torch.nn            4       2            3     LSTM          100
# 689         torch.nn            3       2            3      GRU          100
# 679         torch.nn            4       1            3     LSTM          100
# 296         torch.nn            4       1            3      GRU          100
# 347         torch.nn            4       2            3      GRU          100
# 707         torch.nn            4       2            3      GRU          100
# 48    w2v_pretrained            3       1            3      RNN          100
# 333         torch.nn            4       2            3      RNN          100
# 312         torch.nn            3       1            3      RNN          100
# 290         torch.nn            3       1            3      GRU          100
# 694         torch.nn            4       2            3     LSTM          100
# 499    ft_pretrained            4       1            3     LSTM          100
# 134    ft_pretrained            3       1            3      GRU          100
# 341         torch.nn            3       2            3      GRU          100
# 718         torch.nn            4       2            3     LSTM          100
# 705         torch.nn            4       2            3      RNN          100
# 357         torch.nn            4       2            3      RNN          100
# 489    ft_pretrained            4       2            3      RNN          100
# 482    ft_pretrained            3       1            3      GRU          100
# 108    ft_pretrained            3       1            3      RNN          100
# 667         torch.nn            4       1            3     LSTM          100
# 65    w2v_pretrained            3       2            3      GRU          100
# 210  w2v_selftrained            4       1            3      RNN          100
# 500    ft_pretrained            4       1            3      GRU          100
# 648         torch.nn            3       1            3      RNN          100
# 630   ft_selftrained            4       1            3      RNN          100
# 51    w2v_pretrained            3       2            3      RNN          100
# 430   w2v_pretrained            4       2            3     LSTM          100
# 680         torch.nn            4       1            3      GRU          100
# 351         torch.nn            3       2            3      RNN          100
# 335         torch.nn            4       2            3      GRU          100
# 301         torch.nn            3       1            3     LSTM          100
# 329         torch.nn            3       2            3      GRU          100
# 336         torch.nn            3       1            3      RNN          100
# 472    ft_pretrained            3       2            3     LSTM          100
# 661         torch.nn            3       1            3     LSTM          100
# 563  w2v_selftrained            4       2            3      GRU          100
# 308         torch.nn            4       1            3      GRU          100
# 135    ft_pretrained            3       2            3      RNN          100
# 346         torch.nn            4       2            3     LSTM          100
# 693         torch.nn            4       2            3      RNN          100
# 129    ft_pretrained            4       2            3      RNN          100
# 45    w2v_pretrained            4       2            3      RNN          100
# 319         torch.nn            4       1            3     LSTM          100
# 314         torch.nn            3       1            3      GRU          100
# 402   w2v_pretrained            4       1            3      RNN          100
# 696         torch.nn            3       1            3      RNN          100
# 419   w2v_pretrained            4       2            3      GRU          100
# 67    w2v_pretrained            4       1            3     LSTM          100
# 425   w2v_pretrained            3       2            3      GRU          100
# 353         torch.nn            3       2            3      GRU          100
# 130    ft_pretrained            4       2            3     LSTM          100
# 124    ft_pretrained            3       2            3     LSTM          100
# 670         torch.nn            4       2            3     LSTM          100
# 345         torch.nn            4       2            3      RNN          100
# 420   w2v_pretrained            3       1            3      RNN          100
# 427   w2v_pretrained            4       1            3     LSTM          100
# 717         torch.nn            4       2            3      RNN          100
# 672         torch.nn            3       1            3      RNN          100
# 558  w2v_selftrained            4       1            3      RNN          100
# 688         torch.nn            3       2            3     LSTM          100
# 139    ft_pretrained            4       1            3     LSTM          100
# 493    ft_pretrained            3       1            3     LSTM          100
# 674         torch.nn            3       1            3      GRU          100
# 313         torch.nn            3       1            3     LSTM          100
# 481    ft_pretrained            3       1            3     LSTM          100
# ...
# 78               None  0.6715   0.6800
# 390   xavier_uniform_  0.6715   0.7395
# 435              None  0.6715   0.7403
# 98    xavier_uniform_  0.6714   0.7403
# 377  kaiming_uniform_  0.6714   0.7204
# 107   xavier_uniform_  0.6713   0.7004
# 75               None  0.6711   0.7200
# 106   xavier_uniform_  0.6711   0.7403
# 0                None  0.6711   0.7403
# 466   xavier_uniform_  0.6710   0.7403
# 79               None  0.6709   0.7403
# 34    xavier_uniform_  0.6709   0.7204
# 16   kaiming_uniform_  0.6708   0.6805
# 26    xavier_uniform_  0.6706   0.7204
# 360              None  0.6705   0.7200
# 2                None  0.6705   0.7403
# 204   xavier_uniform_  0.6704   0.7132
# 94   kaiming_uniform_  0.6704   0.7403
# 382  kaiming_uniform_  0.6704   0.7004
# 77               None  0.6703   0.7200
# 445  kaiming_uniform_  0.6703   0.6604
# 35    xavier_uniform_  0.6701   0.7004
# 394   xavier_uniform_  0.6701   0.6805
# 440              None  0.6701   0.7004
# 573   xavier_uniform_  0.6701   0.7569
# 437              None  0.6700   0.7403
# 362              None  0.6699   0.7403
# 464   xavier_uniform_  0.6697   0.7163
# 369              None  0.6695   0.7395
# 446  kaiming_uniform_  0.6694   0.6604
# 388   xavier_uniform_  0.6693   0.6805
# 368              None  0.6692   0.6800
# 448  kaiming_uniform_  0.6691   0.7403
# 371              None  0.6691   0.7200
# 560  kaiming_uniform_  0.6690   0.6906
# 28    xavier_uniform_  0.6690   0.6994
# 33    xavier_uniform_  0.6689   0.6800
# 384   xavier_uniform_  0.6689   0.6604
# 441              None  0.6689   0.7186
# 88   kaiming_uniform_  0.6688   0.7403
# 434              None  0.6687   0.7403
# 81               None  0.6686   0.7186
# 443              None  0.6685   0.7600
# 101   xavier_uniform_  0.6685   0.6994
# 284   xavier_uniform_  0.6684   0.7316
# 201  kaiming_uniform_  0.6683   0.6759
# 15   kaiming_uniform_  0.6682   0.7004
# 455  kaiming_uniform_  0.6680   0.7004
# 385   xavier_uniform_  0.6679   0.6994
# 7                None  0.6679   0.7186
# 460   xavier_uniform_  0.6675   0.7186
# 386   xavier_uniform_  0.6674   0.7588
# 463   xavier_uniform_  0.6673   0.7352
# 74               None  0.6671   0.7200
# 356   xavier_uniform_  0.6669   0.7378
# 639   xavier_uniform_  0.6668   0.5767
# 9                None  0.6666   0.7163
# 184              None  0.6666   0.7163
# 452  kaiming_uniform_  0.6659   0.7395
# 365              None  0.6659   0.7200
# 95   kaiming_uniform_  0.6653   0.7378
# 97    xavier_uniform_  0.6651   0.7200
# 370              None  0.6651   0.6994
# 92   kaiming_uniform_  0.6648   0.7540
# 85   kaiming_uniform_  0.6648   0.7163
# 11               None  0.6647   0.7604
# 494   xavier_uniform_  0.6647   0.7588
# 1                None  0.6646   0.7200
# 83               None  0.6644   0.7604
# 442              None  0.6641   0.7403
# 436              None  0.6640   0.7200
# 76               None  0.6639   0.7803
# 96    xavier_uniform_  0.6636   0.7378
# 363              None  0.6636   0.7588
# 82               None  0.6633   0.7588
# 559  kaiming_uniform_  0.6631   0.7919
# 5                None  0.6631   0.7604
# 14   kaiming_uniform_  0.6630   0.7568
# 13   kaiming_uniform_  0.6628   0.7200
# 627  kaiming_uniform_  0.6625   0.6010
# 72               None  0.6624   0.7163
# 361              None  0.6624   0.7604
# 375  kaiming_uniform_  0.6624   0.7163
# 137   xavier_uniform_  0.6618   0.6192
# 73               None  0.6615   0.7187
# 364              None  0.6611   0.7403
# 421   xavier_uniform_  0.6610   0.7186
# 454  kaiming_uniform_  0.6609   0.7352
# 556  kaiming_uniform_  0.6606   0.6613
# 3                None  0.6606   0.7781
# 10               None  0.6606   0.8003
# 478              None  0.6606   0.7004
# 120  kaiming_uniform_  0.6604   0.7781
# 399              None  0.6603   0.7163
# 459   xavier_uniform_  0.6601   0.7540
# 260              None  0.6597   0.6700
# 395   xavier_uniform_  0.6596   0.7568
# 4                None  0.6594   0.7200
# 686              None  0.6587   0.6722
# 715   xavier_uniform_  0.6581   0.7403
# 69    xavier_uniform_  0.6580   0.6903
# 470              None  0.6578   0.7186
# 398              None  0.6577   0.7974
# 692              None  0.6576   0.6400
# 433              None  0.6575   0.7200
# 142   xavier_uniform_  0.6574   0.7200
# 111              None  0.6572   0.7604
# 36               None  0.6571   0.6800
# 41               None  0.6571   0.7186
# 121  kaiming_uniform_  0.6566   0.6974
# 119              None  0.6561   0.7186
# 404              None  0.6559   0.7200
# 406              None  0.6559   0.7502
# 64    xavier_uniform_  0.6556   0.7186
# 109              None  0.6556   0.7200
# 410  kaiming_uniform_  0.6554   0.7950
# 38               None  0.6551   0.7163
# 68    xavier_uniform_  0.6549   0.7540
# 417  kaiming_uniform_  0.6548   0.6784
# 62    xavier_uniform_  0.6544   0.7759
# 118              None  0.6542   0.7163
# 271  kaiming_uniform_  0.6542   0.7030
# 132   xavier_uniform_  0.6537   0.7604
# 47               None  0.6535   0.7004
# 501   xavier_uniform_  0.6534   0.7403
# 114              None  0.6534   0.7568
# 479              None  0.6532   0.6975
# 673   xavier_uniform_  0.6532   0.7004
# 567   xavier_uniform_  0.6528   0.7269
# 714   xavier_uniform_  0.6525   0.7600
# 138   xavier_uniform_  0.6525   0.6784
# 709   xavier_uniform_  0.6524   0.6406
# 415  kaiming_uniform_  0.6523   0.7204
# 183              None  0.6522   0.7502
# 342  kaiming_uniform_  0.6517   0.7200
# 61    xavier_uniform_  0.6512   0.7781
# 690              None  0.6509   0.7395
# 713   xavier_uniform_  0.6508   0.8003
# 40               None  0.6507   0.7316
# 471              None  0.6501   0.6784
# 412  kaiming_uniform_  0.6494   0.7378
# 37               None  0.6492   0.6604
# 354   xavier_uniform_  0.6489   0.7796
# 133   xavier_uniform_  0.6489   0.6994
# 324              None  0.6489   0.6400
# 50   kaiming_uniform_  0.6488   0.7604
# 127  kaiming_uniform_  0.6485   0.7204
# 495   xavier_uniform_  0.6485   0.7200
# 469              None  0.6484   0.7316
# 207   xavier_uniform_  0.6484   0.6190
# 57   kaiming_uniform_  0.6479   0.7186
# 468              None  0.6477   0.7540
# 409  kaiming_uniform_  0.6475   0.7352
# 490  kaiming_uniform_  0.6473   0.7352
# 431   xavier_uniform_  0.6471   0.7796
# 331              None  0.6469   0.7604
# 685              None  0.6469   0.6571
# 503   xavier_uniform_  0.6468   0.6131
# 474              None  0.6466   0.7600
# 330              None  0.6458   0.6805
# 59   kaiming_uniform_  0.6458   0.7759
# 46               None  0.6457   0.6800
# 687              None  0.6456   0.7395
# 691              None  0.6455   0.7187
# 719   xavier_uniform_  0.6454   0.7403
# 334              None  0.6454   0.6006
# 66    xavier_uniform_  0.6453   0.7403
# 706  kaiming_uniform_  0.6452   0.7004
# 480  kaiming_uniform_  0.6451   0.7604
# 113              None  0.6451   0.6406
# 716   xavier_uniform_  0.6450   0.6785
# 411  kaiming_uniform_  0.6447   0.6353
# 350   xavier_uniform_  0.6445   0.7796
# 344  kaiming_uniform_  0.6444   0.7004
# 704  kaiming_uniform_  0.6444   0.7204
# 697  kaiming_uniform_  0.6443   0.6604
# 397              None  0.6441   0.6192
# 418  kaiming_uniform_  0.6439   0.6205
# 484  kaiming_uniform_  0.6439   0.6805
# 332              None  0.6436   0.8000
# 54   kaiming_uniform_  0.6434   0.7600
# 343  kaiming_uniform_  0.6433   0.7204
# 698  kaiming_uniform_  0.6428   0.7204
# 683   xavier_uniform_  0.6422   0.6400
# 359   xavier_uniform_  0.6421   0.7403
# 695              None  0.6421   0.8400
# 264  kaiming_uniform_  0.6420   0.5390
# 405              None  0.6417   0.7974
# 323   xavier_uniform_  0.6416   0.6205
# 325              None  0.6411   0.6785
# 491  kaiming_uniform_  0.6410   0.7568
# 488  kaiming_uniform_  0.6410   0.7729
# 401              None  0.6408   0.7568
# 654              None  0.6407   0.6800
# 320   xavier_uniform_  0.6405   0.6571
# 326              None  0.6396   0.7604
# 115              None  0.6394   0.7540
# 337  kaiming_uniform_  0.6393   0.6800
# 318   xavier_uniform_  0.6393   0.6805
# 413  kaiming_uniform_  0.6392   0.7502
# 348   xavier_uniform_  0.6392   0.6604
# 327              None  0.6391   0.6192
# 656              None  0.6388   0.7974
# 358   xavier_uniform_  0.6386   0.6192
# 689              None  0.6386   0.6354
# 679   xavier_uniform_  0.6384   0.6168
# 296              None  0.6377   0.6975
# 347  kaiming_uniform_  0.6376   0.8802
# 707  kaiming_uniform_  0.6376   0.6805
# 48   kaiming_uniform_  0.6374   0.7004
# 333              None  0.6374   0.7200
# 312   xavier_uniform_  0.6373   0.7200
# 290              None  0.6368   0.7004
# 694              None  0.6367   0.7395
# 499   xavier_uniform_  0.6366   0.6354
# 134   xavier_uniform_  0.6364   0.6782
# 341  kaiming_uniform_  0.6364   0.7588
# 718   xavier_uniform_  0.6363   0.6192
# 705  kaiming_uniform_  0.6363   0.6994
# 357   xavier_uniform_  0.6358   0.6571
# 489  kaiming_uniform_  0.6358   0.6758
# 482  kaiming_uniform_  0.6354   0.6604
# 108              None  0.6354   0.6849
# 667  kaiming_uniform_  0.6353   0.7378
# 65    xavier_uniform_  0.6353   0.6800
# 210   xavier_uniform_  0.6353   0.6190
# 500   xavier_uniform_  0.6352   0.6800
# 648              None  0.6351   0.6945
# 630  kaiming_uniform_  0.6349   0.5851
# 51   kaiming_uniform_  0.6345   0.7604
# 430   xavier_uniform_  0.6345   0.6975
# 680   xavier_uniform_  0.6343   0.7803
# 351   xavier_uniform_  0.6342   0.6593
# 335              None  0.6340   0.6571
# 301  kaiming_uniform_  0.6339   0.7378
# 329              None  0.6338   0.6994
# 336  kaiming_uniform_  0.6337   0.6784
# 472              None  0.6337   0.6400
# 661  kaiming_uniform_  0.6336   0.7186
# 563  kaiming_uniform_  0.6333   0.7269
# 308  kaiming_uniform_  0.6333   0.6604
# 135   xavier_uniform_  0.6332   0.6181
# 346  kaiming_uniform_  0.6331   0.6192
# 693              None  0.6328   0.7395
# 129  kaiming_uniform_  0.6328   0.7187
# 45               None  0.6326   0.6700
# 319   xavier_uniform_  0.6325   0.7318
# 314   xavier_uniform_  0.6324   0.6994
# 402              None  0.6323   0.6205
# 696  kaiming_uniform_  0.6322   0.6192
# 419  kaiming_uniform_  0.6319   0.7403
# 67    xavier_uniform_  0.6316   0.6722
# 425   xavier_uniform_  0.6313   0.7600
# 353   xavier_uniform_  0.6313   0.7803
# 130  kaiming_uniform_  0.6311   0.6383
# 124  kaiming_uniform_  0.6309   0.6975
# 670  kaiming_uniform_  0.6300   0.7186
# 345  kaiming_uniform_  0.6297   0.6604
# 420   xavier_uniform_  0.6294   0.6758
# 427   xavier_uniform_  0.6294   0.8003
# 717   xavier_uniform_  0.6293   0.7600
# 672   xavier_uniform_  0.6293   0.6000
# 558  kaiming_uniform_  0.6291   0.6278
# 688              None  0.6289   0.6974
# 139   xavier_uniform_  0.6289   0.6400
# 493   xavier_uniform_  0.6289   0.6903
# 674   xavier_uniform_  0.6289   0.7186
# 313   xavier_uniform_  0.6286   0.8003
# 481  kaiming_uniform_  0.6280   0.6945
# 70    xavier_uniform_  0.6278   0.6805
# 473              None  0.6276   0.7200
# 340  kaiming_uniform_  0.6275   0.6975
# 338  kaiming_uniform_  0.6271   0.7568
# 42               None  0.6270   0.6945
# 328              None  0.6269   0.6077
# 307  kaiming_uniform_  0.6267   0.6205
# 669  kaiming_uniform_  0.6266   0.6006
# 311  kaiming_uniform_  0.6261   0.7990
# 483  kaiming_uniform_  0.6260   0.7086
# 306  kaiming_uniform_  0.6256   0.6192
# 310  kaiming_uniform_  0.6254   0.6168
# 684              None  0.6254   0.6613
# 186              None  0.6252   0.6700
# 423   xavier_uniform_  0.6251   0.6944
# 339  kaiming_uniform_  0.6248   0.6604
# 682   xavier_uniform_  0.6247   0.7004
# 298              None  0.6242   0.6205
# 352   xavier_uniform_  0.6240   0.7604
# 711   xavier_uniform_  0.6238   0.7588
# 699  kaiming_uniform_  0.6235   0.7204
# 701  kaiming_uniform_  0.6235   0.6400
# 322   xavier_uniform_  0.6234   0.6674
# 288              None  0.6231   0.6903
# 58   kaiming_uniform_  0.6229   0.7588
# 304  kaiming_uniform_  0.6228   0.6400
# 570   xavier_uniform_  0.6226   0.5537
# 396              None  0.6220   0.6538
# 315   xavier_uniform_  0.6218   0.6353
# 664  kaiming_uniform_  0.6211   0.6383
# 39               None  0.6207   0.7269
# 651              None  0.6205   0.7403
# 477              None  0.6204   0.5495
# 649              None  0.6199   0.6490
# 700  kaiming_uniform_  0.6195   0.7200
# 349   xavier_uniform_  0.6193   0.5597
# 317   xavier_uniform_  0.6184   0.6192
# 289              None  0.6183   0.6758
# 294              None  0.6181   0.7378
# 303  kaiming_uniform_  0.6176   0.6000
# 143   xavier_uniform_  0.6175   0.5903
# 140   xavier_uniform_  0.6170   0.7164
# 52   kaiming_uniform_  0.6165   0.7454
# 44               None  0.6165   0.6994
# 678   xavier_uniform_  0.6165   0.7352
# 658              None  0.6164   0.6784
# 309  kaiming_uniform_  0.6159   0.6400
# 305  kaiming_uniform_  0.6158   0.6903
# 426   xavier_uniform_  0.6154   0.7781
# 128  kaiming_uniform_  0.6154   0.6526
# 677   xavier_uniform_  0.6150   0.7378
# 485  kaiming_uniform_  0.6149   0.7796
# 299              None  0.6140   0.6571
# 63    xavier_uniform_  0.6139   0.7200
# 400              None  0.6139   0.7316
# 675   xavier_uniform_  0.6136   0.7004
# 321   xavier_uniform_  0.6124   0.6974
# 71    xavier_uniform_  0.6124   0.7540
# 665  kaiming_uniform_  0.6124   0.7403
# 671  kaiming_uniform_  0.6118   0.6353
# 712   xavier_uniform_  0.6117   0.6784
# 292              None  0.6101   0.5948
# 53   kaiming_uniform_  0.6068   0.6855
# 126  kaiming_uniform_  0.6067   0.7502
# 676   xavier_uniform_  0.6066   0.6312
# 663  kaiming_uniform_  0.6056   0.6593
# 122  kaiming_uniform_  0.6054   0.6081
# 492   xavier_uniform_  0.6052   0.5427
# 302  kaiming_uniform_  0.6038   0.7588
# 660  kaiming_uniform_  0.6034   0.6974
# 650              None  0.6031   0.6129
# 141   xavier_uniform_  0.6027   0.7030
# 476              None  0.6021   0.7211
# 117              None  0.6018   0.7950
# 131  kaiming_uniform_  0.6012   0.7211
# 293              None  0.6007   0.6429
# 681   xavier_uniform_  0.6007   0.6253
# 496   xavier_uniform_  0.5999   0.5724
# 56   kaiming_uniform_  0.5998   0.6538
# 300  kaiming_uniform_  0.5993   0.6400
# 662  kaiming_uniform_  0.5992   0.7796
# 295              None  0.5992   0.5936
# 653              None  0.5990   0.7318
# 403              None  0.5989   0.6168
# 416  kaiming_uniform_  0.5978   0.7132
# 407              None  0.5977   0.7316
# 60    xavier_uniform_  0.5963   0.6960
# 110              None  0.5961   0.6493
# 652              None  0.5949   0.5169
# 668  kaiming_uniform_  0.5946   0.7130
# 659              None  0.5938   0.6537
# 123  kaiming_uniform_  0.5936   0.6429
# 43               None  0.5932   0.6081
# 355   xavier_uniform_  0.5924   0.6009
# 55   kaiming_uniform_  0.5920   0.6722
# 424   xavier_uniform_  0.5914   0.6782
# 657              None  0.5910   0.6994
# 408  kaiming_uniform_  0.5904   0.7395
# 655              None  0.5903   0.5820
# 666  kaiming_uniform_  0.5885   0.6720
# 702  kaiming_uniform_  0.5884   0.6312
# 297              None  0.5871   0.5664
# 291              None  0.5810   0.6493
# 475              None  0.5795   0.6960
# 116              None  0.5793   0.6722
# 502   xavier_uniform_  0.5768   0.5842
# 112              None  0.5741   0.6258
# 414  kaiming_uniform_  0.5725   0.6975
# 703  kaiming_uniform_  0.5711   0.6006
# 486  kaiming_uniform_  0.5679   0.5509
# 428   xavier_uniform_  0.5522   0.5820
# 708   xavier_uniform_  0.5505   0.5402
# 316   xavier_uniform_  0.5478   0.6312
# 497   xavier_uniform_  0.5451   0.5119
# 125  kaiming_uniform_  0.5412   0.4964
# 487  kaiming_uniform_  0.5406   0.5840
# 422   xavier_uniform_  0.5224   0.5562
# 49   kaiming_uniform_  0.5182   0.5402
# 429   xavier_uniform_  0.5051   0.5724
# 498   xavier_uniform_  0.4913   0.5674
# 710   xavier_uniform_  0.4626   0.4657
